# %%
library(dplyr)
library(tidyr)
library(pheatmap)
library(viridis)
library(tools)
library(cluster)
library(igraph)
library(tibble)

library(clusterProfiler)
library(org.Hs.eg.db)
library(dplyr)

# %%
# 读入
signature_Macro <- read.csv(
  "Example_refbuilder_Macro/ALL_cGEP_top_genes_Mono_Macro_wide_filt.csv",
  check.names = FALSE,
  stringsAsFactors = FALSE
)

# 转成 list（核心）
cluster_genes <- lapply(signature_Macro, function(x) {
  x[!is.na(x) & x != ""]
})
cluster_genes
# Out:
# $cGEP1
#  [1] "IL1B"     "PLAUR"    "C15ORF48" "SRGN"     "SOD2"     "EREG"
#  [7] "NAMPT"    "BCL2A1"   "CXCL8"    "CXCL2"    "G0S2"     "NFKBIA"
# [13] "BTG1"     "SAMSN1"   "AQP9"     "CXCL3"    "FTH1"     "TIMP1"
# [19] "OLR1"     "THBS1"    "PNRC1"    "CD44"     "IER3"     "NLRP3"
# [25] "C5AR1"    "CCL20"    "SAT1"     "TNFAIP3"  "SLC2A3"   "PTGS2"
#
# $cGEP2
#  [1] "HSP90AA1"   "HSPA1A"     "HSPB1"      "HSPA1B"     "DNAJB1"
#  [6] "HSPE1"      "IER5"       "ZFAND2A"    "HSPD1"      "HSPH1"
# [11] "HSPA6"      "DUSP1"      "RHOB"       "BAG3"       "DNAJB4"
# [16] "RGS2"       "UBC"        "MTRNR2L2"   "HSP90AB1"   "AP000769.1"
# [21] "ND3"        "CLK1"       "KLF2"       "DNAJA4"     "UBB"
# [26] "DNAJA1"     "CACYBP"     "RPS4Y1"     "SH3BGRL3"   "SHISAL2A"
#
# $cGEP3
#  [1] "FABP7"         "ZIC5"          "RP11-408N14.1" "RP1-56K13.2"
#  [5] "FGG"           "SPRR1B"        "PRSS57"        "DPP10"
#  [9] "HOXD10"        "RPS18"         "RPS6"          "SFTPA1"
# [13] "SPRR2D"        "SFTPA2"        "AP001171.1"    "RPS23"
# [17] "RPS4X"         "RPL3"          "RPS3"          "POU3F3"
# [21] "RPS12"         "CLDN2"         "RPLP0"         "RPS5"
# [25] "NPM1"          "FGB"           "RPS2"          "RPS7"
# [29] "RPL10A"        "RP11-817J15.2"
#
# $cGEP4
#  [1] "DNAJB1"    "HSPA1B"    "HSPA1A"    "HSP90AA1"  "BAG3"      "HSPB1"
#  [7] "HSPH1"     "HSP90AA2P" "HSPD1"     "HSPA6"     "UBC"       "HSP90AB1"
# [13] "DNAJB1P1"  "JUN"       "DNAJA1"    "ZFAND2A"   "HSPE1"     "HSPA8"
# [19] "IER5"      "HSP90AA4P" "DUSP1"     "DNAJA4"    "ZSCAN12P1" "PCYT1B"
# [25] "PPP1R15A"  "ATF3"      "NR4A1"     "RGS2"      "UBB"       "HSPA7"
#
# $cGEP5
#  [1] "S100A9"        "S100A8"        "LYZ"           "S100A12"
#  [5] "VCAN"          "GAPDH"         "S100A6"        "AC020656.1"
#  [9] "FCN1"          "TSPO"          "PLBD1"         "VIM"
# [13] "CSTA"          "METTL9"        "SELL"          "ATP5MPL"
# [17] "S100A4"        "TKT"           "LGALS1"        "RF00012"
# [21] "CD36"          "S100A10"       "RP11-1143G9.4" "MGST1"
# [25] "RETN"          "SERPINB1"      "CES1"          "ATP5F1E"
# [29] "TALDO1"        "CDA"
#
# $cGEP6
#  [1] "MTCO1P53"      "S100A9"        "RP11-240E2.2"  "S100A8"
#  [5] "LYZ"           "FCN1"          "VCAN"          "S100A12"
#  [9] "Metazoa-SRP"   "RP5-857K21.11" "AC138744.2"    "RP4-635A23.6"
# [13] "AC016739.2"    "SELL"          "MNDA"          "S100A6"
# [17] "TKT"           "LA16C-306A4.2" "RP11-417L19.5" "4h.2"
# [21] "RP3-417G15.1"  "PLBD1"         "CSTA"          "CTD-2649C14.2"
# [25] "RP11-362F19.2" "RP5-857K21.7"  "CTSS"          "TSPO"
# [29] "S100A4"        "CTB-181H17.1"
#
# $cGEP7
#  [1] "AC079325.2"    "FCGR3A"        "LST1"          "C19ORF38"
#  [5] "IFITM2"        "RPS19"         "RHOC"          "CNTN5"
#  [9] "CDKN1C"        "C10ORF54"      "SMIM25"        "IFITM3"
# [13] "AC104809.2"    "AIF1"          "NDNF"          "C15ORF39"
# [17] "NAP1L1"        "AC104809.4"    "LINC01272"     "MS4A7"
# [21] "LOC100130520"  "TCF7L2"        "LINC02334"     "RP5-857K21.11"
# [25] "SERPINA1"      "COTL1"         "FCER1G"        "CD79B"
# [29] "LOC101928037"  "LOC100507639"
#
# $cGEP8
#  [1] "GZMB"         "CLEC4C"       "LILRA4"       "CLIC3"        "SMPD3"
#  [6] "PACSIN1"      "LRRC26"       "TSPAN13"      "PTCRA"        "MZB1"
# [11] "ITM2C"        "IGJ"          "IRF7"         "TLR9"         "JCHAIN"
# [16] "RP11-73G16.2" "IRF4"         "SCT"          "FAM129C"      "LOC101928123"
# [21] "C12orf75"     "TCL1A"        "PPP1R14B"     "CXCR3"        "DERL3"
# [26] "SPIB"         "LOC101929219" "RP1-302G2.5"  "TCF4"         "MAP1A"
#
# $cGEP9
#  [1] "ACP5"       "LGALS3"     "CALR"       "CD63"       "PLA2G7"
#  [6] "FTL"        "CTSB"       "CTSD"       "TGFBI"      "PRDX1"
# [11] "FPR3"       "CAPG"       "CTSL"       "S100A11"    "FABP5"
# [16] "NPC2"       "YBX1"       "PSAP"       "PMP22"      "FABP5P7"
# [21] "IFI30"      "HSP90B1"    "APOE"       "AC026366.1" "PPIB"
# [26] "ATP6V1F"    "ANXA2"      "PCOLCE2"    "HLA-DQA2"   "HLA-DRB5"
#
# $cGEP10
#  [1] "CCR7"       "FSCN1"      "LAMP3"      "BIRC3"      "LAD1"
#  [6] "TXN"        "EBI3"       "CCL19"      "AL109741.1" "MARCKSL1"
# [11] "IDO1"       "CCL22"      "AC007216.2" "SLCO5A1"    "SINHCAF"
# [16] "HMSD"       "CD200"      "NUB1"       "GPR157"     "AOC1"
# [21] "TBC1D4"     "AC112719.2" "LIMCH1"     "BX255923.3" "RAB9A"
# [26] "PPA1"       "CSF2RA"     "DAPP1"      "BCL2L14"    "KIF2A"
#
# $cGEP11
#  [1] "AC245427.1"   "IL32"         "CD3D"         "CD3E"         "PTPRCAP"
#  [6] "TRAC"         "GZMA"         "CD2"          "TRBC2"        "CD3G"
# [11] "LCK"          "CCL5"         "LOC101929531" "NKG7"         "CD7"
# [16] "TRBC1"        "GZMM"         "CTSW"         "KLRB1"        "CST7"
# [21] "SPOCK2"       "CD247"        "GZMH"         "CD27"         "AP002004.1"
# [26] "ETS1"         "GNLY"         "CD8A"         "PRF1"         "PCED1B-AS1"
#
# $cGEP12
#  [1] "CTC-575D19.1"   "HLA-DPB1"       "HLA-DPA1"       "HLA-DRA"
#  [5] "HLA-DQB1"       "HLA-DQA1"       "CD74"           "CTD-2192J16.15"
#  [9] "HLA-DRB1"       "HLA-DRB6"       "FCER1A"         "CD1C"
# [13] "CLEC10A"        "AC005251.3"     "RPS2"           "RPS18"
# [17] "RP3-406A7.3"    "CTD-2014B16.2"  "RP11-318C24.1"  "CST3"
# [21] "RPS23"          "RP11-51O6.1"    "RPL3"           "RPL23A"
# [25] "RPL15"          "RP4-800G7.1"    "RP11-215A21.2"  "RP11-492M23.2"
# [29] "RPS6"           "RPL10A"
#
# $cGEP13
#  [1] "CTSK"        "MMP9"        "CKB"         "SIGLEC15"    "SLC9B2"
#  [6] "ACP5"        "AK5"         "NDRG4"       "CST3"        "AP000904.1"
# [11] "MT-RNR1"     "TCIRG1"      "THOP1"       "SPINK2"      "ANXA8L1"
# [16] "ATP6V0D2"    "S100A3"      "ITGB3"       "MYH16"       "RGS10"
# [21] "SLC22A1"     "HTRA3"       "DPP4"        "HSPB7"       "COL6A2"
# [26] "HYAL1"       "MTATP6P1"    "BAMBI"       "MT-RNR2"     "RP11-54O7.1"
#
# $cGEP14
#  [1] "JUN"      "FOS"      "HSPA1B"   "DUSP1"    "SFTPC"    "SFTPA1"
#  [7] "DNAJB1"   "RHOB"     "IER2"     "ATF3"     "KLF2"     "C1QA"
# [13] "C1QC"     "EGR1"     "HSPA1A"   "UBC"      "RGS1"     "GADD45B"
# [19] "ITM2B"    "C1QB"     "JUNB"     "ZFP36L2"  "NR4A2"    "KLF4"
# [25] "SEPP1"    "HERPUD1"  "HSP90AA1" "GPR34"    "TXNIP"    "FCGR3A"
#
# $cGEP15
#  [1] "NKG7"       "GZMB"       "GZMA"       "GNLY"       "FGFBP2"
#  [6] "PRF1"       "CST7"       "CTSW"       "GZMH"       "KLRD1"
# [11] "SPON2"      "ADGRG1"     "CLIC3"      "HOPX"       "S1PR5"
# [16] "GZMM"       "IL2RB"      "CD247"      "XCL2"       "AL158071.4"
# [21] "TBX21"      "KIR2DL1"    "KLRF1"      "TRDC"       "CCL4"
# [26] "CD7"        "PTGDR"      "CD160"      "ZMAT4"      "PRSS23"
#
# $cGEP16
#  [1] "APOE"          "CTSD"          "GPNMB"         "APOC1"
#  [5] "RP11-368J21.3" "LGMN"          "CTSB"          "PSAP"
#  [9] "C1QB"          "PLD3"          "ACP5"          "FTL"
# [13] "C1QC"          "LIPA"          "CD63"          "C1QA"
# [17] "PLA2G7"        "CD68"          "FUCA1"         "CAPG"
# [21] "PRDX1"         "RP11-696F12.1" "ASAH1"         "GRN"
# [25] "CTSZ"          "TREM2"         "HLA-DRB4"      "LGALS3"
# [29] "CTSL"          "CTSC"
#
# $cGEP17
#  [1] "FO538757.3"    "MPIG6B"        "PPBP"          "PF4"
#  [5] "GNG11"         "GP9"           "TUBB1"         "SDPR"
#  [9] "SPARC"         "CAVIN2"        "HRAT92"        "CMTM5"
# [13] "TREML1"        "SPTB"          "CLU"           "C6orf25"
# [17] "NRGN"          "HIST1H2AC"     "AP001189.1"    "ITGA2B"
# [21] "MYL9"          "SEPT5"         "GRAP2"         "TUBA8"
# [25] "TMEM40"        "DMTN"          "CTTN"          "RP11-678G14.3"
# [29] "PDLIM1"        "RP11-185E8.1"
#
# $cGEP18
#  [1] "MTRNR2L5"      "C1QB"          "NPC2"          "ATXN8OS"
#  [5] "CD74"          "NAPSB"         "C1QC"          "TREM2"
#  [9] "PCED1B-AS1"    "CTC-471J1.9"   "AL353644.10"   "B2M"
# [13] "PSME2P2"       "AC004448.5"    "HLA-DPA1"      "C1QA"
# [17] "HLA-DRA"       "TMSB4X"        "RP11-680H20.1" "ALOX5AP"
# [21] "HLA-DRB1"      "FCER1G"        "HLA-DMB"       "UBBP4"
# [25] "COX6A1P2"      "FYB1"          "ATP5F1A"       "JPT1"
# [29] "VSIR"          "TYROBP"
#
# $cGEP19
#  [1] "C1QA"          "SELENOP"       "C1QB"          "C1QC"
#  [5] "FOLR2"         "AC008945.2"    "DAB2"          "GGTA1P"
#  [9] "CYTB"          "LGMN"          "SEPP1"         "SLCO2B1"
# [13] "SLC40A1"       "PLTP"          "MS4A4A"        "MAF"
# [17] "RNR2"          "CD163"         "A2M"           "STAB1"
# [21] "FCGRT"         "GIMAP1-GIMAP5" "GPR126"        "RNASE1"
# [25] "ATP6"          "MRC1"          "MS4A7"         "SDC3"
# [29] "CTSC"          "KIAA0247"
#
# $cGEP20
#  [1] "AC109326.1"      "RF00012"         "MTATP6P1"        "MTND1P23"
#  [5] "RNU1-1"          "AC018445.4"      "CCL3"            "CCL4"
#  [9] "MT-TM"           "AC011676.5"      "AC087284.1"      "MTND2P28"
# [13] "CCL3L1"          "AC122718.1"      "CCL4L2"          "CD83"
# [17] "RNU1-2"          "ENSG00000206828" "RN7SL473P"       "RNVU1-19"
# [21] "ENSG00000273727" "RNVU1-15"        "IER3"            "RNU1-4"
# [25] "MT-RNR2"         "EGR1"            "AC104581.4"      "CCL3L3"
# [29] "RNU6-6P"         "KLF6"
#
# $cGEP21
#  [1] "CTD-3252C9.4"  "LGALS2"        "RPPH1"         "LINC00936"
#  [5] "DUSP6"         "FGL2"          "ATP5E"         "ZFP36"
#  [9] "NEAT1"         "NFKBIA"        "IL1B"          "ZFP36L1"
# [13] "RP11-160E2.6"  "MARCKS"        "PID1"          "ATP5I"
# [17] "DUSP1"         "FOS"           "TCEB2"         "CPVL"
# [21] "FYB1"          "CD4"           "CCL3L3"        "LAP3"
# [25] "NAMPT"         "SAMHD1"        "JUND"          "FTH1"
# [29] "AHNAK"         "RP11-430G17.3"
#
# $cGEP22
#  [1] "CSTB"       "GPNMB"      "FTL"        "AC106788.1" "CTSD"
#  [6] "CTSB"       "SPP1"       "ANXA2"      "CD63"       "LGALS3"
# [11] "TM4SF19"    "VIM"        "LGALS1"     "APOC1"      "CAPG"
# [16] "CTSL"       "CD68"       "CHI3L1"     "FABP5"      "MMP9"
# [21] "CYP27A1"    "CD9"        "FTH1"       "NUPR1"      "LIPA"
# [26] "GAPDH"      "FBP1"       "APOE"       "SDC2"       "CHIT1"
#
# $cGEP23
#  [1] "AC090109.1"    "AC104964.2"    "TPSB2"         "Z84492.1"
#  [5] "CPA3"          "AL357556.4"    "TPSAB1"        "HDC"
#  [9] "RHEX"          "KIT"           "AC090236.2"    "SLC18A2"
# [13] "PRG2"          "MS4A2"         "C1ORF186"      "AC022960.1"
# [17] "HPGD"          "IL1RL1"        "GATA2"         "MAOB"
# [21] "AL645568.2"    "KCTD9P1"       "HDGFP1"        "CTSG"
# [25] "SIGLEC17P"     "TPSD1"         "SVOPL"         "RP11-354E11.2"
# [29] "ADCYAP1"       "AL161756.1"
#
# $cGEP24
#  [1] "KRT6A"     "KRT16"     "KRT6B"     "KRT6C"     "KRT14"     "PERP"
#  [7] "LY6D"      "S100A7"    "KRTDAP"    "DMKN"      "AQP3"      "SFN"
# [13] "SBSN"      "TRIML1"    "LGALS7B"   "S100A14"   "KRT17"     "SERPINB4"
# [19] "S100A16"   "SPRR1B"    "S100A8"    "SERPINB3"  "KRT1"      "GJB2"
# [25] "DSP"       "OVOL1-AS1" "KRT5"      "LINC01527" "KRT10"     "PI3"
#
# $cGEP25
#  [1] "CCL3L1"     "GPR183"     "RGS1"       "AC016831.5" "CD83"
#  [6] "AREG"       "NFKBIA"     "SRGN"       "HLA-DQB1"   "REL"
# [11] "ZFP36"      "JUNB"       "CXCR4"      "HNRNPA1P48" "NR4A3"
# [16] "NR4A1"      "RPL3"       "NR4A2"      "RACK1"      "OLR1"
# [21] "SGK1"       "HLA-DPB1"   "FAM64A"     "ID2"        "DUSP2"
# [26] "IL1B"       "HLA-DRB5"   "HLA-DRA"    "ZNF331"     "RPS4X"
#
# $cGEP26
#  [1] "ISG15"    "GBP1"     "TNFSF10"  "IFIT3"    "CXCL10"   "IFIT1"
#  [7] "MX1"      "CXCL11"   "IFITM3"   "IFIT2"    "IFI6"     "LY6E"
# [13] "HLA.B"    "EPSTI1"   "HLA.C"    "ISG20"    "RSAD2"    "IFI44L"
# [19] "LAP3"     "B2M"      "APOBEC3A" "GBP4"     "CALHM6"   "IDO1"
# [25] "PPAPDC2"  "TYMP"     "IGLC1"    "STAT1"    "UBE2L6"   "OAS1"
#
# $cGEP27
#  [1] "RPL26P19"      "RP11-20O24.4"  "GAPDH"         "RP13-258O15.1"
#  [5] "VIM"           "S100A10"       "RPL9P9"        "EEF1A1P5"
#  [9] "AC092484.1"    "MIF"           "RPL37A"        "AC011933.2"
# [13] "CSTB"          "TMSB4XP6"      "ENO1"          "MCEMP1"
# [17] "LDHA"          "FBP1"          "LGALS1"        "RP11-466H18.1"
# [21] "TPI1"          "S100A6"        "SH3BGRL3"      "RPL23AP74"
# [25] "RPS29"         "RPS27"         "RPL41"         "FTLP3"
# [29] "RP11-83J16.1"  "RPS28"
#
# $cGEP28
#  [1] "BX005266.2"    "IGKV1-6"       "IGHV3-15"      "IGKV1D-39"
#  [5] "IGHV3OR16-13"  "MZB1"          "LOC102723766"  "IGKC"
#  [9] "IGKV1D-16"     "IGHG1"         "JCHAIN"        "IGKV1-17"
# [13] "IGHV3-23"      "IGHG2"         "IGHG4"         "IGHG3"
# [17] "IGJ"           "IGKV1D-17"     "DERL3"         "AC007386.4"
# [21] "CH17-212P11.4" "TNFRSF17"      "OR4C13"        "AC107464.3"
# [25] "IGHGP"         "IGKV3-20"      "FKBP11"        "RP11-16E12.2"
# [29] "CD27"          "IGHA1"
#
# $cGEP29
#  [1] "HLA-DPA1"     "CD74"         "HLA-DQB1"     "FCER1A"       "HLA-DPB1"
#  [6] "PLD4"         "LOC100996809" "HLA-DRB5"     "PKIB"         "GSN"
# [11] "HLA-DRA"      "NDRG2"        "CD1E"         "NAPSB"        "CD1C"
# [16] "CXorf36"      "HLA-DRB4"     "HLA-DRB1"     "ALOX5AP"      "CHAD"
# [21] "HLA-DQA2"     "RGS1"         "HLA-DQA1"     "HERPUD1"      "HLA-DMA"
# [26] "CDH17"        "PLEK2"        "CD207"        "FCGR2B"       "HLA-DQB2"
#
# $cGEP30
#  [1] "IL8"           "RPL13"         "RPL32"         "RP11-463O12.5"
#  [5] "RPLP2"         "TPT1"          "RPS16"         "RPL10"
#  [9] "RPS24"         "RPL34"         "RPLP1"         "RPL28"
# [13] "FOSB"          "MIR24-2"       "RPS14"         "RPS12"
# [17] "RPS18"         "RPL18A"        "RPS8"          "RPL13A"
# [21] "RPL30"         "RPS23"         "RPL11"         "RPL37"
# [25] "RPL26"         "RPL35A"        "RPS15A"        "RPL37A"
# [29] "RPL9"          "RPS3A"
#
# $cGEP31
#  [1] "MT-CO2"       "MT-CYB"       "MT-ATP6"      "MT-ND1"       "MT-ND4"
#  [6] "MT-CO3"       "MT-CO1"       "MT-ND3"       "MT-ND5"       "MT-ND2"
# [11] "ND4L"         "ATP8"         "ND3"          "CYTB"         "COX3"
# [16] "MT-ND4L"      "XIST"         "COX2"         "COX1"         "ND1"
# [21] "ND5"          "ATP6"         "MALAT1"       "RNR2"         "RNA45S5"
# [26] "MTRNR2L12"    "ND6"          "LOC101928412" "ND4"          "ND2"
#
# $cGEP32
#  [1] "C1QB"       "C1QA"       "C1QC"       "C3"         "PLTP"
#  [6] "A2M"        "FCGBP"      "OLR1"       "RNASET2"    "SCIN"
# [11] "NR4A3"      "CTSB"       "SLC11A1"    "ATP1B3"     "SLC16A3"
# [16] "PADI2"      "ACSL1"      "SPP1"       "SLC2A5"     "LAPTM5"
# [21] "HIF1A"      "SLC7A5"     "GPR183"     "SCGB2A1"    "C1ORF54"
# [26] "TNFRSF1B"   "PLAUR"      "CD83"       "SNAP47-AS1" "C5AR1"
#
# $cGEP33
#  [1] "KLK2"       "KLK3"       "RDH11"      "ACPP"       "TMPRSS2"
#  [6] "STEAP2"     "KL"         "SLC45A3"    "AZGP1"      "CPE"
# [11] "MME"        "MSMB"       "DHCR24"     "ORM1"       "DHRS7"
# [16] "BMPR1B-AS1" "NKX3-1"     "STEAP1"     "FOXA1"      "NCAPD3"
# [21] "PLPP1"      "DSP"        "CDH1"       "SLC30A4"    "SLC44A4"
# [26] "SYT7"       "RAB3B"      "FXYD3"      "MLPH"       "LIFR"
#
# $cGEP34
#  [1] "GeneID:645079" "LOC101928215"  "LOC101929371"  "MARCO"
#  [5] "RBP4"          "FBP1"          "LOC100505592"  "GPD1"
#  [9] "FABP4"         "RP11-77A13.1"  "GCHFR"         "MCEMP1"
# [13] "AOC3"          "ALDH2"         "LPL"           "AL109754.1"
# [17] "S100A11"       "FN1"           "LGALS3"        "PCOLCE2"
# [21] "LTA4H"         "CD52"          "VSIG4"         "GRN"
# [25] "CES1"          "APOC1"         "FTLP3"         "SERPINA1"
# [29] "C1QB"          "IGFBP2"
#
# $cGEP35
#  [1] "FAM212A"       "CCDC176"       "RP1-34B20.21"  "LINC00863"
#  [5] "TMEM40"        "RP11-879F14.1" "RP11-88H9.2"   "RAB27B"
#  [9] "C10orf10"      "PTCRA"         "ACRBP"         "RP11-367G6.3"
# [13] "RP11-879F14.2" "RGS18"         "FAM212B-AS1"   "TSC22D1"
# [17] "HIST1H2BJ"     "HEMGN"         "RGCC"          "HRAT92"
# [21] "NT5C3A"        "HIST1H2AC"     "PRUNE"         "SMOX"
# [25] "PCP2"          "CLDN5"         "LAT"           "LGALSL"
# [29] "RP11-501J20.5" "SDPR"
#
# $cGEP36
#  [1] "MCM10"   "TYMS"    "TK1"     "C2orf48" "PCNA"    "CDC45"   "FAM111B"
#  [8] "PCLAF"   "CLSPN"   "CDT1"    "DTL"     "HELLS"   "GINS2"   "H2AFZ"
# [15] "FEN1"    "MCM6"    "RRM2"    "DUT"     "CENPU"   "ATAD2"   "PKMYT1"
# [22] "CENPM"   "TUBB"    "CCNE2"   "MYBL2"   "ZWINT"   "CDC6"    "MCM4"
# [29] "DHFR"    "MCM3"
#
# $cGEP37
#  [1] "HSP90AA2P"  "PLIN2"      "HSPE1-MOB4" "ADM"        "CSTB"
#  [6] "GAPDH"      "LDHA"       "HK2"        "HSP90AA1"   "DNAJB1"
# [11] "HSP90AA4P"  "SLC2A1"     "NUPR1"      "HSPH1"      "BNIP3"
# [16] "HSPA1A"     "SLC2A3"     "HILPDA"     "BAG3"       "FTH1"
# [21] "VIM"        "HSP90AB3P"  "ERO1A"      "HSPB1"      "ENO1"
# [26] "MIF"        "FTH1P8"     "NDRG1"      "HSPA1B"     "HSPB1P1"
#
# $cGEP38
#  [1] "TOP2A"      "MKI67"      "UBE2C"      "TUBB"       "STMN1"
#  [6] "AC091133.2" "NUSAP1"     "KIAA0101"   "HIST1H4C"   "GSTM2P1"
# [11] "TUBA1B"     "CDC20"      "CENPF"      "BIRC5"      "HMMR"
# [16] "TPX2"       "CDKN3"      "HMGB2"      "TYMS"       "CDK1"
# [21] "H2AFZ"      "AURKB"      "HMGB1"      "ASPM"       "DLGAP5"
# [26] "CKS1B"      "GTSE1"      "CEP55"      "RRM2"       "CCNB2"
#
# $cGEP39
#  [1] "CD74"          "HLA-DRB1"      "HLA-DPB1"      "HLA-DPA1"
#  [5] "HLA-DRA"       "HLA-DQA1"      "IGHD"          "HLA-DQB1"
#  [9] "IGHM"          "CST3"          "HLA-DMA"       "GYLTL1B"
# [13] "RPL15"         "RPL10"         "CLEC10A"       "RP11-693J15.5"
# [17] "RACK1"         "RPS18"         "RPS2"          "RPL3"
# [21] "HLA-DMB"       "RPS4X"         "RPL4"          "PF4V1"
# [25] "EEF1A1"        "RPS6"          "RPS8"          "TCL1A"
# [29] "LINC01013"     "C6orf25"
#
# $cGEP40
#  [1] "LINC02397"  "CD79A"      "MS4A1"      "TCL1A"      "IGHM"
#  [6] "FAM129C"    "LINC00926"  "FCRLA"      "IGHD"       "BLK"
# [11] "TNFRSF13C"  "EBF1"       "IGKC"       "VPREB3"     "FCER2"
# [16] "POU2AF1"    "CD19"       "FCRL1"      "TNFRSF13B"  "LINC01013"
# [21] "CD79B"      "BANK1"      "AL139020.1" "PAX5"       "IGHV5-51"
# [26] "CD22"       "COBLL1"     "FAM30A"     "FCMR"       "PLEKHG1"
#
# $cGEP41
#  [1] "RHEX"       "LINC02206"  "CLEC9A"     "LINC01724"  "AL118508.1"
#  [6] "DNASE1L3"   "IDO1"       "CLNK"       "C1orf54"    "CADM1"
# [11] "CCND1"      "BFSP2"      "WDFY4"      "NAPSB"      "XCR1"
# [16] "CPNE3"      "GCSAM"      "SNX3"       "HLA-DOB"    "AL161645.1"
# [21] "PPY"        "RAB7B"      "AC080038.1" "LINC01976"  "HLA-DPB1"
# [26] "AC060234.2" "IRF8"       "AC016205.1" "CNGB3"      "CPVL"
#
# $cGEP42
#  [1] "CAPS"         "C9orf24"      "TSPAN19"      "CCDC160"      "SNTN"
#  [6] "RP4-666F24.3" "TMEM190"      "C20orf85"     "ACSBG1"       "FAM183A"
# [11] "CAPSL"        "C1orf194"     "PIFO"         "CFAP53"       "C5orf49"
# [16] "RSPH1"        "C11orf70"     "TPPP3"        "C10orf67"     "C9orf135"
# [21] "RSPH4A"       "AGR3"         "FAM216B"      "SLC23A1"      "RP4-625H18.2"
# [26] "HHLA2"        "SYT8"         "SLC6A14"      "ANKK1"        "PRMT8"
#
# $cGEP43
#  [1] "HLA-DRB4"     "LOC100996809" "PSME2"        "TMSB10"       "YWHAH"
#  [6] "S100A11"      "HLA-DRB3"     "FAM26F"       "ACTB"         "PFN1"
# [11] "GSN"          "CD74"         "CFL1"         "ATP5G3"       "ANXA2"
# [16] "VCX2"         "OTULINL"      "ANGPTL8"      "TYMP"         "CRP"
# [21] "PSMB3"        "PSMB9"        "CTSH"         "TPI1"         "HLA-DQB1"
# [26] "VAMP8"        "CLEC10A"      "HLA-DMA"      "ANKRD22"      "PPIB"
#
# $cGEP44
#  [1] "COL1A1"  "COL1A2"  "COL3A1"  "SPARC"   "LUM"     "RARRES2" "DCN"
#  [8] "SFRP2"   "AEBP1"   "RPS26"   "BGN"     "IGFBP7"  "CALD1"   "COL6A3"
# [15] "ACTA2"   "TIMP3"   "COL6A2"  "COMP"    "TAGLN"   "CTGF"    "MYL9"
# [22] "MGP"     "CCDC80"  "MMP11"   "TPM2"    "CTHRC1"  "COL6A1"  "NBL1"
# [29] "THBS2"   "CXCL14"
#
# $cGEP45
#  [1] "FXYD3"      "AKR1C2"     "PERP"       "S100A2"     "GPX2"
#  [6] "KRT19"      "KRT6A"      "SFN"        "AKR1C1"     "AKR1C3"
# [11] "TACSTD2"    "KRT8"       "KRT18"      "CLDN4"      "AKR1B10"
# [16] "SOX2"       "NQO1"       "TM4SF1"     "KLF5"       "GAGE2A"
# [21] "S100A16"    "LY6D"       "KRT5"       "MAL2"       "GSTP1"
# [26] "DSP"        "AL162376.1" "LIM2"       "C19orf33"   "EPCAM"
#
# $cGEP46
#  [1] "RP1-60O19.1"  "PNCK"         "ADIRF"        "NNMT"         "NDUFA4L2"
#  [6] "CD24"         "TMEM27"       "RP11-124N2.1" "UGT2B7"       "ANGPTL4"
# [11] "RARRES2"      "CA9"          "CYB5A"        "CA12"         "FXYD2"
# [16] "CXCL14"       "HSPB8"        "CRYAB"        "REG1A"        "WFDC2"
# [21] "FSBP"         "IGFBP3"       "HPN"          "KRT8"         "KRT18"
# [26] "SLC22A2"      "GAL3ST1"      "RBP5"         "RP1-317E23.6" "BHMT"
#
# $cGEP47
#  [1] "FABP6"          "TRIM55"         "KCNK9"          "TSPY10"
#  [5] "FCGR3A"         "MEG3"           "SPAG6"          "BMP4"
#  [9] "LINC01781"      "PCGF2"          "RHOC"           "GRIK4"
# [13] "MIR99AHG"       "FRZB"           "RP11-1008C21.1" "IGF1"
# [17] "LINC02362"      "KCNJ3"          "STEAP1"         "LINC01272"
# [21] "FAM27C"         "AL139002.1"     "CDKN1C"         "RPS19"
# [25] "HES4"           "NAP1L1"         "TMEM45A"        "AC109809.1"
# [29] "MS4A7"          "RP11-221J22.2"
#
# $cGEP48
#  [1] "S100A9"     "SH3BGRL3"   "MYL6"       "EMP3"       "S100A8"
#  [6] "ANXA2"      "SERF2"      "CD163"      "S100A11"    "S100A10"
# [11] "TIMP1"      "S100A6"     "FCER1G"     "MARCO"      "CFL1"
# [16] "LGALS1"     "AL445524.1" "PFN1"       "S100A4"     "ACTB"
# [21] "SELENOT"    "SDF2L1"     "AP2S1"      "CD14"       "SLC39A8"
# [26] "RIPOR2"     "POMP"       "HSP90B1"    "CALR"       "NOP10"
#
# $cGEP49
#  [1] "CCL3L3"        "CCL3"          "CCL4"          "IL1B"
#  [5] "NFKBIA"        "CCL4L2"        "ZFP36"         "BCL2A1"
#  [9] "CXCL3"         "TNF"           "PSME2"         "SOD2"
# [13] "CXCL2"         "IER3"          "KB-1507C5.4"   "PLAC8"
# [17] "CXCL8"         "SRGN"          "GADD45B"       "HLA-DRB1"
# [21] "HLA-DRA"       "GBP1"          "CH17-373J23.1" "APOBEC3A"
# [25] "ATP5EP2"       "IFITM3"        "CD83"          "PPP1R15A"
# [29] "VAMP5"         "NCF1"
#
# $cGEP50
#  [1] "COL3A1"        "COL1A2"        "COL1A1"        "DCX"
#  [5] "RP11-166D19.1" "LUM"           "SPARC"         "DCN"
#  [9] "C8ORF4"        "POSTN"         "COL5A2"        "COL6A3"
# [13] "AC025822.2"    "COL5A1"        "COL6A2"        "CTHRC1"
# [17] "HAPLN1"        "CTGF"          "COL6A1"        "AEBP1"
# [21] "ISLR"          "CALD1"         "EGFL6"         "BGN"
# [25] "RP11-119F7.5"  "PCOLCE"        "MXRA5"         "WNT2"
# [29] "EPYC"          "HSPB1P1"
#
# $cGEP51
#  [1] "CCL3L1"       "CCL3"         "CCL3L3"       "CCL4"         "IL1B"
#  [6] "CCL4L2"       "TNF"          "NFKBIA"       "CD83"         "PPP1R15A"
# [11] "ZFP36"        "JUN"          "GADD45B"      "FOS"          "IER2"
# [16] "IER3"         "ATF3"         "TNFAIP3"      "JUNB"         "KLF6"
# [21] "CXCL8"        "FOSB"         "RP3-393E18.2" "NR4A1"        "DUSP2"
# [26] "IL1A"         "NFKBIZ"       "SOD2"         "SGK1"         "NR4A2"
#
# $cGEP52
#  [1] "C1QB"    "C1QA"    "C1QC"    "PLTP"    "MARCO"   "CST3"    "HAMP"
#  [8] "CD163"   "RPS27L"  "SEPP1"   "CXCL12"  "TSPAN13" "PSAP"    "FN1"
# [15] "IFI27"   "FOLR2"   "LYVE1"   "CD14"    "CTSL"    "SLC2A5"  "TMSB4X"
# [22] "CFD"     "MPC2"    "AIF1"    "MT2A"    "BHLHE41" "VAMP5"   "TIMD4"
# [29] "CXADR"   "MS4A4A"
#
# $cGEP53
#  [1] "RGS1"         "SNHG7"        "CD37"         "RGS10"        "EEF1A1"
#  [6] "EIF4A2"       "KRT5"         "YPEL3"        "SCUBE2"       "ZFP36L2"
# [11] "EPB41L4A-AS1" "CEBPD"        "NPM1"         "CCNI"         "CDKN1C"
# [16] "HLA-DPB1"     "CIRBP"        "EVI2B"        "RPL3"         "TXNIP"
# [21] "RPS4X"        "HERPUD1"      "EVI2A"        "RPS3"         "RPL31"
# [26] "C10orf54"     "PCNXL2"       "C10orf11"     "DNAJB1"       "EEF2"
#
# $cGEP54
#  [1] "C1QC"     "C1QB"     "C1QA"     "CTSC"     "HLA-C"    "FCGR3A"
#  [7] "SLC40A1"  "LGALS3BP" "HLA-DRB1" "B2M"      "IFI6"     "TYROBP"
# [13] "CD14"     "TMEM176B" "CD74"     "HLA-A"    "STAT1"    "ITM2B"
# [19] "FCGR2A"   "HLA-DQA1" "LY6E"     "FCER1G"   "CTSB"     "HLA-DMB"
# [25] "EPSTI1"   "BST2"     "GRN"      "HLA-DRA"  "SERPING1" "TYMP"
#
# $cGEP55
#  [1] "HBB"      "CA1"      "HBD"      "ESPN"     "HBA1"     "HBA2"
#  [7] "AHSP"     "ALAS2"    "HBG1"     "HBM"      "SLC4A1"   "GYPA"
# [13] "GYPB"     "EPB42"    "MRC2"     "SLC25A37" "SNCA"     "STRADB"
# [19] "SLC25A39" "PRDX2"    "PDZK1IP1" "BLVRB"    "CR2"      "DCAF12"
# [25] "FECH"     "SELENBP1" "OSBP2"    "HEMGN"    "TMEM56"   "CDH1"
#
# $cGEP56
#  [1] "DUSP1"     "AREG"      "FOS"       "SAMSN1"    "SOCS3"     "ZFP36"
#  [7] "SRGN"      "IL1B"      "MAT2A"     "ZNF331"    "NAMPT"     "SERPINB2"
# [13] "RGS2"      "JUNB"      "TNFAIP3"   "CD55"      "THBS1"     "SLC2A3"
# [19] "FKBP5"     "CLEC4E"    "IL1R2"     "ACSL1"     "LITAF"     "MCL1"
# [25] "NR4A2"     "GK"        "SAT1"      "CDKN1A"    "FAM65B"    "LOC731424"
#
# $cGEP57
#  [1] "DCN"      "FBLN1"    "MGP"      "IGFBP6"   "PLAC9"    "CCDC80"
#  [7] "C1R"      "MFAP4"    "EFEMP1"   "CFD"      "C1S"      "SFRP1"
# [13] "DPT"      "SOD3"     "GSN"      "IGFBP5"   "ADH1B"    "LUM"
# [19] "PRELP"    "FGF7"     "WISP2"    "HSPB6"    "TIMP3"    "IGFBP4"
# [25] "OGN"      "PCOLCE2"  "SPARCL1"  "APOD"     "SERPINF1" "PLD5"
#
# $cGEP58
#  [1] "PBK"        "UGT3A2"     "MS4A1"      "AC025437.4" "ATP2A1-AS1"
#  [6] "RDM1"       "ELL3"       "ELOVL6"     "PACSIN3"    "IGLL1"
# [11] "VAT1L"      "GINS2"      "GALNT14"    "VPREB1"     "RPGRIP1L"
# [16] "HMGB1"      "CCDC81"     "ZNF470"     "PIMREG"     "DSCC1"
# [21] "IGHD"       "CDKN3"      "PTMA"       "HPDL"       "PPIA"
# [26] "FABP5"      "GINS3"      "ZNF771"     "DKK2"       "TUBA1B"
#
# $cGEP59
#  [1] "CTSG"      "PLD4"      "LGALS1"    "DHRS3"     "ENHO"      "H2AFZ"
#  [7] "HMGN2"     "ACTG1"     "FABP5"     "PDE6G"     "HOXB-AS3"  "MRPL33"
# [13] "PTMA"      "PPIA"      "PHACTR3"   "METTL7B"   "CXorf21"   "STMN1"
# [19] "RNASE2"    "DBI"       "MCM2"      "IGFBP7"    "ACOT7"     "CFL1"
# [25] "PHGDH"     "MCM6"      "SH3BP4"    "HMGN1"     "HLA-DQA2"  "HNRNPA2B1"
#
# $cGEP60
#  [1] "TSPAN8"     "TFF1"       "AGR2"       "KRT19"      "FXYD3"
#  [6] "ELF3"       "KRT8"       "S100P"      "EPCAM"      "MUC1"
# [11] "WFDC2"      "CEACAM6"    "TM4SF1"     "TMC5"       "SMIM22"
# [16] "KRT18"      "C19orf33"   "LMO7"       "AL033384.1" "GPRC5A"
# [21] "TFF2"       "LGALS4"     "MAL2"       "CTSE"       "CLDN4"
# [26] "TM4SF4"     "SPINK1"     "CEACAM5"    "SLPI"       "OCIAD2"
#
# $cGEP61
#  [1] "PRAME"         "TNC"           "TUSC3"         "ZNF462"
#  [5] "IGFBP5"        "SCHIP1"        "DRGX"          "WWC1"
#  [9] "TAGLN3"        "MEX3A"         "PCLO"          "C18orf42"
# [13] "STRA6"         "MDK"           "KIF26A"        "SNAP25"
# [17] "CRYBA2"        "CNTN2"         "TJP1"          "MAP2"
# [21] "GALNTL6"       "STMN1"         "largeTAntigen" "SLC44A3"
# [25] "HPCA"          "RORB"          "SHD"           "CCK"
# [29] "PLEKHA6"       "ENAH"
#
# $cGEP62
#  [1] "HSPD1"    "HSPH1"    "HSPB1"    "FKBP4"    "BAG3"     "HSP90AA1"
#  [7] "HSP90AB1" "HSPA1A"   "CHORDC1"  "CACYBP"   "HSPA8"    "HSPE1"
# [13] "MRPL18"   "SERPINH1" "AHSA1"    "HLA-DPB1" "SNX3"     "DOK2"
# [19] "ZFAND2A"  "DNAJB6"   "TCP1"     "PTGES3"   "DNAJA1"   "DNAJB1"
# [25] "NUDC"     "SNAP23"   "ST13"     "P4HA1"    "HSPA4L"   "STIP1"
#
# $cGEP63
#  [1] "UNC80"      "STMN2"      "UBE2QL1"    "IFITM2"     "BARHL1"
#  [6] "SLC25A37"   "S100A8"     "CSF3R"      "KCNJ6"      "MNDA"
# [11] "KIF5A"      "VNN2"       "NAMPT"      "FCGR3B"     "CDA"
# [16] "GCA"        "ALOX5AP"    "S100A9"     "RIPOR2"     "ANP32A"
# [21] "AL355601.1" "CMTM2"      "RGL4"       "CYP4F3"     "S100A12"
# [26] "DRAIC"      "ACSL1"      "DRD1"       "XKR4"       "NCF1"
#
# $cGEP64
#  [1] "SPARCL1"   "CLU"       "INMT"      "C1orf61"   "NTRK2"     "GPM6B"
#  [7] "CPE"       "MT3"       "GFAP"      "PTN"       "PTPRZ1"    "ATP1B2"
# [13] "IL33"      "SLC1A2"    "TTYH1"     "TOMM20P1"  "ID4"       "ABCD2"
# [19] "GJA1"      "TRIL"      "CST3"      "ITM2C"     "TSC22D4"   "AQP4"
# [25] "LRRC4C"    "C17orf100" "FBLN7"     "SPARC"     "AGT"       "SCG3"
#
# $cGEP65
#  [1] "LINC01986"  "KRT18"      "KRT8"       "MDK"        "YWHAE"
#  [6] "WFDC2"      "SPINT2"     "CD24"       "ELF3"       "KRT19"
# [11] "EPCAM"      "CD47"       "RPL8"       "MMP7"       "PDZK1IP1"
# [16] "MTCH1"      "LCN2"       "HSP90AB1"   "RARRES1"    "TM4SF1"
# [21] "AL512274.1" "LY6E"       "CLPS"       "C6orf132"   "BCAM"
# [26] "KRT17"      "CD9"        "BEX3"       "LHX1"       "ASRGL1"
#
# $cGEP66
#  [1] "CRABP2"     "CHI3L1"     "MMP7"       "COL22A1"    "MMP12"
#  [6] "SPP1"       "TMEM114"    "CSTB"       "LPL"        "CHIT1"
# [11] "SLAMF9"     "SDC2"       "LINC02345"  "CD52"       "AC084809.2"
# [16] "FBP1"       "IFI6"       "PAQR5"      "AL117379.1" "SPOCD1"
# [21] "AC015660.2" "GPC4"       "AC244033.2" "SLC12A8"    "CLVS1"
# [26] "MMP9"       "SH3BGRL3"   "HCST"       "ATP6V0D2"   "RAC2"
#
# $cGEP67
#  [1] "RP11-160O5.1" "FABP4"        "GPC4"         "SPOCD1"       "CRABP2"
#  [6] "LPL"          "TM4SF19"      "GDF15"        "SPP1"         "HOXB6"
# [11] "CHI3L1"       "TREM2"        "TIMP3"        "COL6A2"       "FCGBP"
# [16] "TBX1"         "GPNMB"        "EPB41L1"      "USP2"         "ITGA3"
# [21] "PLD3"         "APOE"         "GPR150"       "FABP5"        "CTSD"
# [26] "LIPA"         "CADM1"        "GOLGA7B"      "FTL"          "APOC1"
#
# $cGEP68
#  [1] "BFSP1"      "IGFBP7"     "COL5A3"     "SPARCL1"    "COL4A1"
#  [6] "FGF1"       "GUCY1A1"    "CALD1"      "PLXDC1"     "SPARC"
# [11] "KCNJ8"      "TPPP3"      "THY1"       "CACNA1C"    "CAVIN3"
# [16] "MGP"        "SLC2A4"     "AC107294.2" "PRSS23"     "COX4I2"
# [21] "NDUFA4L2"   "COL6A2"     "PRF1"       "SOD3"       "C15orf62"
# [26] "RGS5"       "CCDC102B"   "COL3A1"     "COL15A1"    "GJC1"
#
# $cGEP69
#  [1] "C14orf2"   "MT-CO2"    "MT-ATP6"   "RPL34"     "MT-ND2"    "RPS3A"
#  [7] "RPS27A"    "MT-ND4"    "RPL7"      "MT-CYB"    "RPL39"     "RPS15A"
# [13] "RPL26"     "RPL21"     "RPS24"     "MT-ND5"    "RPL9"      "RPL30"
# [19] "RPS27"     "COX7B"     "MT-ND3"    "MT-CO3"    "S100A12"   "ATP5E"
# [25] "COL1A1"    "COL1A2"    "SUB1"      "ESD"       "LINC00998" "RPS25"
#
# $cGEP70
#  [1] "AL935026.1" "HLA-DQA1"   "LOR"        "HLA-DRB5"   "HLA-DQB1"
#  [6] "IDO1"       "PPA1"       "CCR7"       "EDARADD"    "LAMP3"
# [11] "CST7"       "EBI3"       "FSCN1"      "NAPSB"      "TVP23A"
# [16] "LAD1"       "HLA-DPA1"   "CXCL9"      "SPIB"       "HLA-DRB1"
# [21] "CD207"      "HLA-DPB1"   "TIFAB"      "CD1E"       "BIRC3"
# [26] "CALHM6"     "CD74"       "PSME2"      "CLEC10A"    "AC008429.2"
#
# $cGEP71
#  [1] "IGKC"    "IGHGP"   "LY6K"    "IGHG1"   "SNHG25"  "SCGB1D2" "S100A1"
#  [8] "MT-ND1"  "IGHG3"   "PCP4"    "IGHG4"   "IGLC7"   "MT-ND2"  "FBXO2"
# [15] "MT-CO2"  "CD209"   "MT-ATP6" "PART1"   "MT-ND4"  "IGHM"    "OLFM3"
# [22] "PNMT"    "IGLC3"   "CCL13"   "RPS20"   "DSCR8"   "MT-ND3"  "TNNT1"
# [29] "MT-ND5"  "HES1"
#
# $cGEP72
#  [1] "NDUFA4L2" "WFDC1"    "MYLK"     "ACTA2"    "MCAM"     "PPP1R14A"
#  [7] "COL4A1"   "RGS5"     "CAV1"     "IGFBP7"   "TAGLN"    "MYL9"
# [13] "TINAGL1"  "COL4A2"   "SPARCL1"  "PLN"      "COX4I2"   "CALD1"
# [19] "LURAP1L"  "AVPR1A"   "LHFP"     "CAP2"     "MYH11"    "LMOD1"
# [25] "KCNJ8"    "DKK3"     "EFHD1"    "COL18A1"  "PDLIM1"   "NOTCH3"
#
# $cGEP73
#  [1] "PPP1R15A" "UBC"      "GADD45B"  "KLF4"     "NRIP3"    "JUN"
#  [7] "HSPA6"    "IRS2"     "MAP1LC3B" "ANXA1"    "HSPA1A"   "RGCC"
# [13] "HSPA1B"   "PHLDA2"   "ZBTB43"   "EIF1"     "SLC38A2"  "PHLDA1"
# [19] "IER2"     "FOSB"     "ARC"      "DUSP1"    "UBB"      "HSPA8"
# [25] "HMOX1"    "DNAJB1"   "CITED2"   "SGK1"     "CSRNP1"   "HCAR3"
#
# $cGEP74
#  [1] "CTRB2"      "CLPS"       "AC104046.1" "CTRC"       "FTLP3"
#  [6] "REG1A"      "FABP5P7"    "PRSS1"      "CPA1"       "PLA2G1B"
# [11] "CTRB1"      "MTND1P23"   "CPB1"       "PNLIP"      "CEL"
# [16] "CELA3A"     "SLC4A4"     "SYCN"       "FXYD2"      "FABP5P1"
# [21] "GP2"        "AC016739.1" "TREM2"      "MTATP6P1"   "A2M"
# [26] "AMY2A"      "CPA2"       "FABP5"      "PNLIPRP1"   "CD9"
#
# $cGEP75
#  [1] "TCF15"    "SPARCL1"  "MEOX2"    "IGFBP7"   "POSTN"    "PCDH17"
#  [7] "CYP4B1"   "ACKR1"    "FMO2"     "GALNT18"  "MMRN2"    "FILIP1"
# [13] "MGP"      "DOC2B"    "VWF"      "C1QTNF9"  "CLDN5"    "AQP1"
# [19] "MATN2"    "C7"       "PALMD"    "CNTNAP3B" "ADGRF5"   "GPIHBP1"
# [25] "IGFBP3"   "FAM162B"  "HOXD8"    "CCDC3"    "RAMP2"    "MMRN1"
#
# $cGEP76
#  [1] "PODN"       "PLAC9"      "CCDC80"     "ADH1B"      "CCDC3"
#  [6] "OGN"        "FBLN1"      "LUM"        "GTSE1-DT"   "CILP"
# [11] "IL32"       "ISM1"       "GREM1"      "PCDHGB7"    "OR52A1"
# [16] "DPT"        "ISLR"       "C7"         "DNER"       "SCGB1A1"
# [21] "AC108463.3" "MGP"        "AC008555.5" "ENAM"       "GZMA"
# [26] "CCL5"       "IL7R"       "CD3D"       "AC025271.4" "CD2"
#
# $cGEP77
#  [1] "APOBEC3A"      "FFAR2"         "IL1RN"         "CXCL10"
#  [5] "RP11-525A16.4" "NRN1"          "CCL7"          "CTD-2001C12.1"
#  [9] "AP000704.5"    "LILRA5"        "ESPN"          "APOBEC3B"
# [13] "IFIT1"         "CXCL11"        "FJX1"          "CALY"
# [17] "ISG15"         "CCL2"          "ACOX2"         "TNFSF10"
# [21] "RAB36"         "HSPA1A"        "GBP1"          "RP11-7F18.2"
# [25] "FCGR3B"        "TRAV17"        "ACTB"          "TRAV14DV4"
# [29] "KIAA1107"      "FKBP1C"

# %%
convert_gene <- function(gene_symbol_vector){
  bitr(gene_symbol_vector, 
       fromType = "SYMBOL",
       toType = "ENTREZID",
       OrgDb = org.Hs.eg.db) %>%
    pull(ENTREZID)
}

clean_symbol <- function(x){
  x <- unique(x)
  x <- x[x != ""]
  x <- toupper(x)
  x
}

cluster_genes <- lapply(cluster_genes, clean_symbol)

# %%
library(clusterProfiler)
library(org.Hs.eg.db)
library(ReactomePA)
library(msigdbr)
library(dplyr)

# ============================
# 清洗基因名
# ============================
clean_symbol <- function(x){
  x <- unique(toupper(x))
  x[x != ""]
}

cluster_genes <- lapply(cluster_genes, clean_symbol)

# ============================
# SYMBOL → ENTREZ 映射
# ============================
all_symbols <- unique(unlist(cluster_genes))

symbol2entrez <- bitr(all_symbols,
                      fromType="SYMBOL",
                      toType="ENTREZID",
                      OrgDb=org.Hs.eg.db)

# named vector
map_table <- symbol2entrez$ENTREZID
names(map_table) <- symbol2entrez$SYMBOL

# ============================
# MSigDB Hallmark gene sets
# ============================
msig_h <- msigdbr(species = "Homo sapiens", category = "H")

hallmark_list <- msig_h %>% 
  split(.$entrez_gene) %>%
  lapply(function(x) x$gs_name)

# ============================
# 初始化结果表
# ============================
kegg_list <- list()
go_bp_list <- list()
reactome_list <- list()
hallmark_list_results <- list()

# ============================
# 循环 77 clusters
# ============================
for(cl in names(cluster_genes)){

  message("Processing ", cl, " ...")

  # SYMBOL → ENTREZ
  genes <- cluster_genes[[cl]]
  genes_entrez <- map_table[genes]
  genes_entrez <- genes_entrez[!is.na(genes_entrez)]

  if(length(genes_entrez) < 5){
    warning(cl, ": <5 valid genes → skip")
    next
  }

  # KEGG（可以为空）
  kegg_list[[cl]] <- tryCatch({
    enrichKEGG(gene = genes_entrez, organism = "hsa",
               pvalueCutoff = 0.1)
  }, error=function(e) NULL)

  # GO BP
  go_bp_list[[cl]] <- enrichGO(gene = genes_entrez, 
                               OrgDb = org.Hs.eg.db,
                               keyType="ENTREZID",
                               ont="BP",
                               pvalueCutoff=0.1)

  # Reactome（强烈推荐）
  reactome_list[[cl]] <- enrichPathway(gene = genes_entrez,
                                       pvalueCutoff = 0.1,
                                       readable = TRUE)

  # Hallmark enrichment
  hallmark_list_results[[cl]] <- enricher(
    gene = genes_entrez,
    TERM2GENE = msig_h[,c("gs_name","entrez_gene")],
    pvalueCutoff = 0.1
  )
}
# Out:
# Warning message:
# “程辑包‘clusterProfiler’是用R版本4.2.2 来建造的”
#
#
# Registered S3 methods overwritten by 'treeio':
#   method              from
#   MRCA.phylo          tidytree
#   MRCA.treedata       tidytree
#   Nnode.treedata      tidytree
#   Ntip.treedata       tidytree
#   ancestor.phylo      tidytree
#   ancestor.treedata   tidytree
#   child.phylo         tidytree
#   child.treedata      tidytree
#   full_join.phylo     tidytree
#   full_join.treedata  tidytree
#   groupClade.phylo    tidytree
#   groupClade.treedata tidytree
#   groupOTU.phylo      tidytree
#   groupOTU.treedata   tidytree
#   is.rooted.treedata  tidytree
#   nodeid.phylo        tidytree
#   nodeid.treedata     tidytree
#   nodelab.phylo       tidytree
#   nodelab.treedata    tidytree
#   offspring.phylo     tidytree
#   offspring.treedata  tidytree
#   parent.phylo        tidytree
#   parent.treedata     tidytree
#   root.treedata       tidytree
#   rootnode.phylo      tidytree
#   sibling.phylo       tidytree
#
# clusterProfiler v4.6.0  For help: https://yulab-smu.top/biomedical-knowledge-mining-book/
#
# If you use clusterProfiler in published research, please cite:
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal enrichment tool for interpreting omics data. The Innovation. 2021, 2(3):100141
#
#
# 载入程辑包：‘clusterProfiler’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# 载入需要的程辑包：AnnotationDbi
#
# 载入需要的程辑包：stats4
#
# 载入需要的程辑包：BiocGenerics
#
#
# 载入程辑包：‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# 载入需要的程辑包：Biobase
#
# Warning message:
# “程辑包‘Biobase’是用R版本4.2.3 来建造的”
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# 载入需要的程辑包：IRanges
#
# Warning message:
# “程辑包‘IRanges’是用R版本4.2.3 来建造的”
# 载入需要的程辑包：S4Vectors
#
#
# 载入程辑包：‘S4Vectors’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
#
# 载入程辑包：‘IRanges’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
#
# 载入程辑包：‘AnnotationDbi’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
#
# ReactomePA v1.42.0  For help: https://yulab-smu.top/biomedical-knowledge-mining-book/
#
# If you use ReactomePA in published research, please cite:
# Guangchuang Yu, Qing-Yu He. ReactomePA: an R/Bioconductor package for reactome pathway analysis and visualization. Molecular BioSystems 2016, 12(2):477-479
#
# Warning message:
# “程辑包‘dplyr’是用R版本4.2.3 来建造的”
#
# 载入程辑包：‘dplyr’
#
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# 'select()' returned 1:many mapping between keys and columns
#
# Warning message in bitr(all_symbols, fromType = "SYMBOL", toType = "ENTREZID", OrgDb = org.Hs.eg.db):
# “15.78% of input gene IDs are fail to map...”
# Processing cGEP1 ...
#
# Reading KEGG annotation online: "https://rest.kegg.jp/link/hsa/pathway"...
#
# Reading KEGG annotation online: "https://rest.kegg.jp/list/pathway"...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP2 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP3 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP4 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP5 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP6 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP7 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP8 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP9 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP10 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP11 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP12 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP13 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP14 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP15 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP16 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP17 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP18 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP19 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP20 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP21 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP22 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP23 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP24 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP25 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP26 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP27 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP28 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID: 6319,2878,658,8916,226,1622
#
# --> return NULL...
#
# Processing cGEP29 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP30 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP31 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP32 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP33 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP34 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP35 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP36 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP37 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP38 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP39 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP40 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP41 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP42 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP43 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP44 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP45 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP46 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP47 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP48 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP49 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP50 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP51 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP52 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP53 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP54 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP55 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP56 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP57 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP58 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP59 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP60 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP61 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP62 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP63 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP64 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP65 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP66 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP67 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP68 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP69 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP70 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP71 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP72 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP73 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP74 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP75 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP76 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP77 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...

# %%
library(openxlsx)
library(dplyr)

wb <- createWorkbook()

# ===== 1. Hallmark =====
hallmark_df <- bind_rows(
  lapply(names(hallmark_list_results), function(cl){
    res <- hallmark_list_results[[cl]]@result
    if (is.null(res) || nrow(res)==0) return(NULL)
    res$Cluster <- cl
    res
  })
)

addWorksheet(wb, "Hallmark")
writeData(wb, "Hallmark", hallmark_df)

# ===== 2. Reactome =====
reactome_df <- bind_rows(
  lapply(names(reactome_list), function(cl){
    res <- reactome_list[[cl]]@result
    if (is.null(res) || nrow(res)==0) return(NULL)
    res$Cluster <- cl
    res
  })
)

addWorksheet(wb, "Reactome")
writeData(wb, "Reactome", reactome_df)

# ===== 3. GO BP =====
go_bp_df <- bind_rows(
  lapply(names(go_bp_list), function(cl){
    res <- go_bp_list[[cl]]@result
    if (is.null(res) || nrow(res)==0) return(NULL)
    res$Cluster <- cl
    res
  })
)

addWorksheet(wb, "GO_BP")
writeData(wb, "GO_BP", go_bp_df)

# ===== 保存 Excel 文件 =====
saveWorkbook(wb, "./3.2.Macro_GEP_pathway/3.2.Macro_Cluster_Pathway_Results.xlsx", overwrite = TRUE)

# %%
library(openxlsx)
library(dplyr)
library(readr)
library(stringr)

# ==============================================================================
# 1. 读取 Jaccard 注释结果
# ==============================================================================
JACCARD_FILE <- "/sibcb1/bioinformatics/yangyue/project/immunotherapy/7.4.cNMF_Mono_Macro/3.1.Macro_GEP_Anno/3.Mono_Macro_cGEP_Annotation_Results.csv"

if (file.exists(JACCARD_FILE)) {
  anno_df <- read_csv(JACCARD_FILE, show_col_types = FALSE)
  # 强制重命名第一列为 Cluster
  colnames(anno_df)[1] <- "Cluster"
  cat("✅ 成功读取 CSV。列名预览:", colnames(anno_df), "\n")
} else {
  stop("❌ 找不到文件！")
}

# ==============================================================================
# 2. 定义辅助函数 (已修复 select 冲突)
# ==============================================================================

# 函数1: 提取 Top 3 通路摘要
extract_top_summary <- function(enrich_list, db_prefix) {
  df_list <- lapply(names(enrich_list), function(cl) {
    res <- enrich_list[[cl]]@result
    
    if (is.null(res) || nrow(res) == 0) {
      return(data.frame(Cluster = cl, Pathways = "", stringsAsFactors = FALSE))
    }
    
    # 筛选显著并取前3
    top_res <- res %>% 
      filter(p.adjust < 0.05) %>% 
      arrange(p.adjust) %>% 
      head(3)
    
    path_str <- paste(top_res$Description, collapse = " | ")
    
    data.frame(Cluster = cl, Pathways = path_str, stringsAsFactors = FALSE)
  })
  
  combined_df <- bind_rows(df_list)
  
  # 重命名列 (使用 Base R 避免报错)
  target_col <- paste0("Top_", db_prefix)
  colnames(combined_df)[colnames(combined_df) == "Pathways"] <- target_col
  
  return(combined_df)
}

# 函数2: 提取详情 (【核心修复】：使用 dplyr::select)
extract_detail_df <- function(enrich_list) {
  bind_rows(lapply(names(enrich_list), function(cl) {
    res <- enrich_list[[cl]]@result
    if (is.null(res) || nrow(res) == 0) return(NULL)
    
    res$Cluster <- cl
    
    # 【这里修改了】：强制使用 dplyr::select，防止被 AnnotationDbi 覆盖
    res %>% dplyr::select(Cluster, everything())
  }))
}

# ==============================================================================
# 3. 执行提取与合并
# ==============================================================================
cat("正在提取 Hallmark...\n")
hallmark_sum <- extract_top_summary(hallmark_list_results, "Hallmark")
hallmark_det <- extract_detail_df(hallmark_list_results)

cat("正在提取 Reactome...\n")
reactome_sum <- extract_top_summary(reactome_list, "Reactome")
reactome_det <- extract_detail_df(reactome_list)

cat("正在提取 GO_BP...\n")
go_bp_sum    <- extract_top_summary(go_bp_list, "GO_BP")
go_bp_det    <- extract_detail_df(go_bp_list)

# 合并到总表
final_anno_df <- anno_df %>%
  left_join(hallmark_sum, by = "Cluster") %>%
  left_join(reactome_sum, by = "Cluster") %>%
  left_join(go_bp_sum,    by = "Cluster")

# ==============================================================================
# 4. 写入 Excel
# ==============================================================================
OUT_XLSX <- "./3.2.Macro_GEP_pathway/3.3.Macro_Cluster_Pathway_Master_Annotation.xlsx"
wb <- createWorkbook()

# Sheet 1: 总览
addWorksheet(wb, "Summary_Overview")
writeData(wb, "Summary_Overview", final_anno_df)
freezePane(wb, "Summary_Overview", firstRow = TRUE)

# Sheet 2: Hallmark 详情
addWorksheet(wb, "Detail_Hallmark")
writeData(wb, "Detail_Hallmark", hallmark_det)

# Sheet 3: Reactome 详情
addWorksheet(wb, "Detail_Reactome")
writeData(wb, "Detail_Reactome", reactome_det)

# Sheet 4: GO_BP 详情
addWorksheet(wb, "Detail_GO_BP")
writeData(wb, "Detail_GO_BP", go_bp_det)

saveWorkbook(wb, OUT_XLSX, overwrite = TRUE)

cat("--------------------------------------------------\n")
cat("✅ 成功！所有冲突已修复。\n")
cat("📄 文件已保存至:", OUT_XLSX, "\n")
cat("--------------------------------------------------\n")
# Out:
# Warning message:
# “程辑包‘readr’是用R版本4.2.3 来建造的”
# ✅ 成功读取 CSV。列名预览: Cluster Spectra_Label Overlap_Count Jaccard_Score Key_Markers Top_5_Genes_Input
# 正在提取 Hallmark...
# 正在提取 Reactome...
# 正在提取 GO_BP...
# --------------------------------------------------
# ✅ 成功！所有冲突已修复。
# 📄 文件已保存至: ./3.2.Macro_GEP_pathway/3.3.Macro_Cluster_Pathway_Master_Annotation.xlsx
# --------------------------------------------------
