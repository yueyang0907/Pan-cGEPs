# %%
library(dplyr)
library(tidyr)
library(pheatmap)
library(viridis)
library(tools)
library(cluster)
library(igraph)
library(tibble)

library(clusterProfiler)
library(org.Hs.eg.db)
library(dplyr)
# Out:
# Warning message:
# “程辑包‘dplyr’是用R版本4.2.3 来建造的”
#
# 载入程辑包：‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# “程辑包‘tidyr’是用R版本4.2.3 来建造的”
# Warning message:
# “程辑包‘viridis’是用R版本4.2.3 来建造的”
# 载入需要的程辑包：viridisLite
#
# Warning message:
# “程辑包‘viridisLite’是用R版本4.2.3 来建造的”
# Warning message:
# “程辑包‘cluster’是用R版本4.2.3 来建造的”
#
# 载入程辑包：‘igraph’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     crossing
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     as_data_frame, groups, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
#
# 载入程辑包：‘tibble’
#
#
# The following object is masked from ‘package:igraph’:
#
#     as_data_frame
#
#
# Warning message:
# “程辑包‘clusterProfiler’是用R版本4.2.2 来建造的”
#
#
# Registered S3 methods overwritten by 'treeio':
#   method              from
#   MRCA.phylo          tidytree
#   MRCA.treedata       tidytree
#   Nnode.treedata      tidytree
#   Ntip.treedata       tidytree
#   ancestor.phylo      tidytree
#   ancestor.treedata   tidytree
#   child.phylo         tidytree
#   child.treedata      tidytree
#   full_join.phylo     tidytree
#   full_join.treedata  tidytree
#   groupClade.phylo    tidytree
#   groupClade.treedata tidytree
#   groupOTU.phylo      tidytree
#   groupOTU.treedata   tidytree
#   is.rooted.treedata  tidytree
#   nodeid.phylo        tidytree
#   nodeid.treedata     tidytree
#   nodelab.phylo       tidytree
#   nodelab.treedata    tidytree
#   offspring.phylo     tidytree
#   offspring.treedata  tidytree
#   parent.phylo        tidytree
#   parent.treedata     tidytree
#   root.treedata       tidytree
#   rootnode.phylo      tidytree
#   sibling.phylo       tidytree
#
# clusterProfiler v4.6.0  For help: https://yulab-smu.top/biomedical-knowledge-mining-book/
#
# If you use clusterProfiler in published research, please cite:
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal enrichment tool for interpreting omics data. The Innovation. 2021, 2(3):100141
#
#
# 载入程辑包：‘clusterProfiler’
#
#
# The following object is masked from ‘package:igraph’:
#
#     simplify
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# 载入需要的程辑包：AnnotationDbi
#
# 载入需要的程辑包：stats4
#
# 载入需要的程辑包：BiocGenerics
#
#
# 载入程辑包：‘BiocGenerics’
#
#
# The following objects are masked from ‘package:igraph’:
#
#     normalize, path, union
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# 载入需要的程辑包：Biobase
#
# Warning message:
# “程辑包‘Biobase’是用R版本4.2.3 来建造的”
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# 载入需要的程辑包：IRanges
#
# Warning message:
# “程辑包‘IRanges’是用R版本4.2.3 来建造的”
# 载入需要的程辑包：S4Vectors
#
#
# 载入程辑包：‘S4Vectors’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
#
# 载入程辑包：‘IRanges’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
#
# 载入程辑包：‘AnnotationDbi’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select

# %%
# 读入
signature_CD8T <- read.csv(
  "./3.cGEP_topgene/ALL_cGEP_top_genes_long_wide_by_cGEP1_70.csv",
  check.names = FALSE,
  stringsAsFactors = FALSE
)

# 转成 list（核心）
cluster_genes <- lapply(signature_CD8T, function(x) {
  x[!is.na(x) & x != ""]
})
cluster_genes
# Out:
# $cGEP1
#  [1] "TotalSeqC0953" "RP11-864N7.2"  "RP11-234A1.1"  "RP11-425L10.1"
#  [5] "RPL13P12"      "RPS12"         "TotalseqC0251" "RPL13"
#  [9] "RPL32"         "AC024293.1"    "EEF1A1"        "RPL34"
# [13] "AC016739.2"    "RPS18"         "RPS28"         "RPS3A"
# [17] "RPL18AP3"      "RPL39"         "RPL10"         "RPL11"
# [21] "RPS14"         "RPS8"          "RPL30"         "RPS23"
# [25] "RPS6"          "RPS13"         "RPL19"         "RPL37"
# [29] "RPL18A"        "RPS27"
#
# $cGEP2
#  [1] "ISG15"   "MX1"     "IFI6"    "IFIT3"   "IFIT1"   "RSAD2"   "OAS1"
#  [8] "IFI44L"  "ISG20"   "LY6E"    "IFITM1"  "CMPK2"   "HERC5"   "IRF7"
# [15] "OAS3"    "MX2"     "EPSTI1"  "PLSCR1"  "STAT1"   "MT2A"    "USP18"
# [22] "IFIT2"   "IFI35"   "EIF2AK2" "XAF1"    "IFI44"   "SAMD9L"  "TNFSF10"
# [29] "OASL"    "LAMP3"
#
# $cGEP3
#  [1] "CYTB"         "ATP6"         "COX3"         "ND4L"         "COX2"
#  [6] "ND1"          "ND5"          "ND2"          "ATP8"         "RPS14P3"
# [11] "ND3"          "MT-ND1"       "GAS5"         "MT-CO3"       "MT-CO2"
# [16] "ND4"          "HLA-H"        "MT-ND2"       "MT-ND3"       "MT-ATP6"
# [21] "LOC100507217" "MT-CYB"       "MT-ND4"       "MT-ND4L"      "MT-ND5"
# [26] "MT-CO1"       "ND6"          "MT-RNR2"      "AC026366.1"   "CRISP3"
#
# $cGEP4
#  [1] "RPL13P12"      "TotalSeqC0952" "EEF1A1"        "TotalSeqC0955"
#  [5] "RPL13"         "RPL34"         "TPT1"          "RPL32"
#  [9] "RPS12"         "AC010343.1"    "RPLP1"         "AL365357.1"
# [13] "IL7R"          "RPS4XP22"      "RPS8"          "AC016739.1"
# [17] "RPS6"          "RPL10"         "RPL11"         "RPS4X"
# [21] "RPS18"         "AL590867.2"    "RPS14"         "RPS13"
# [25] "CCR7"          "FTH1"          "RPS3A"         "RPL30"
# [29] "RPL3"          "RPL19"
#
# $cGEP5
#  [1] "MT-ND4"    "MT-CO2"    "MT-CO3"    "MT-ATP6"   "MT-CYB"    "MT-CO1"
#  [7] "MT-ND2"    "MT-ND1"    "MT-ND3"    "MT-ND5"    "SLIT1"     "PVRL4"
# [13] "MT-ND4L"   "MTATP6P1"  "MT-RNR1"   "TMPRSS11F" "ANKRD30A"  "MTRNR2L10"
# [19] "RFX6"      "MT-TH"     "MT-RNR2"   "WARS2-IT1" "PABPC4L"   "KCNN2"
# [25] "RNF225"    "SCGB1D2"   "MTRNR2L9"  "TMSB4XP8"  "MT-ATP8"   "MTRNR2L8"
#
# $cGEP6
#  [1] "GAPDH"        "KRT86"        "GZMB"         "ENTPD1"       "TNFRSF9"
#  [6] "TIGIT"        "TNFRSF18"     "CD7"          "LAYN"         "AC092580.4"
# [11] "LOC101929531" "SNX9"         "ALOX5AP"      "TPI1"         "CXCL13"
# [16] "TNS3"         "PGAM1"        "PKM"          "HAVCR2"       "AC002331.1"
# [21] "RBPJ"         "PDLIM4"       "LAG3"         "CTSD"         "ITGAE"
# [26] "CTLA4"        "GOLIM4"       "IFITM10"      "MYO1E"        "CD82"
#
# $cGEP7
#  [1] "RP11-1033A18.1" "DNAJB1"         "HSP90AA1"       "HSPA1A"
#  [5] "RP11-485G4.2"   "HSPA1B"         "HSPH1"          "HSP90AB1"
#  [9] "HSPE1"          "HSPD1"          "HSPA8"          "DNAJA1"
# [13] "RP11-153M3.1"   "CACYBP"         "HSP90AA2P"      "GOT2P2"
# [17] "UBB"            "HSPB1"          "BAG3"           "ZFAND2A"
# [21] "TIMM8AP1"       "HSPA6"          "GGNBP1"         "PPP1R15A"
# [25] "UBC"            "RP11-142L4.2"   "HSP90AB3P"      "MIRLET7D"
# [29] "SERPINH1"       "LOC101928304"
#
# $cGEP8
#  [1] "GNLY"     "S100A4"   "TMSB10"   "TRBV7-6"  "IFITM2"   "RPL39"
#  [7] "S100A6"   "TRAV8-1"  "ATP5E"    "SH3BGRL3" "SERF2"    "FXYD5"
# [13] "MT-ND3"   "RPL41"    "MYL12A"   "S100A11"  "TMSB4X"   "RPS4Y1"
# [19] "GZMB"     "RPL36A"   "TMA7"     "HSPA1A"   "RPS18"    "OST4"
# [25] "RPS21"    "S100A10"  "TRAV10"   "HCST"     "PFN1"     "IFITM1"
#
# $cGEP9
#  [1] "HBB"      "HBD"      "AHSP"     "SNCA"     "CA1"      "HBA2"
#  [7] "ALAS2"    "HBA1"     "SLC4A1"   "SELENBP1" "SLC25A37" "PDZK1IP1"
# [13] "TRIM58"   "HBM"      "HBQ1"     "GMPR"     "HEMGN"    "KLHL33"
# [19] "KLF1"     "SLC25A39" "HBG2"     "STRADB"   "EPB42"    "PLEK2"
# [25] "BLVRB"    "NFIX"     "NFE2"     "TNS1"     "BNIP3L"   "IGF2BP2"
#
# $cGEP10
#  [1] "KLRB1"         "SLC4A10"       "NCR3"          "AMICA1"
#  [5] "CEBPD"         "IL7R"          "LTB"           "S100A4"
#  [9] "DUSP1"         "CCR6"          "LTK"           "ZBTB16"
# [13] "AQP3"          "NFKBIA"        "IL23R"         "IL4I1"
# [17] "TSPAN15"       "RP11-693N9.2"  "ME1"           "RORC"
# [21] "LST1"          "CD69"          "RORA"          "CTD-3014M21.1"
# [25] "IL18RAP"       "IL22"          "CCL20"         "IL26"
# [29] "CTSH"          "PHACTR2"
#
# $cGEP11
#  [1] "FOS"      "JUN"      "DUSP1"    "FOSB"     "COX1"     "KLF6"
#  [7] "CD69"     "JUNB"     "ZFP36"    "TSC22D3"  "ND4"      "TNFAIP3"
# [13] "NFKBIA"   "PPP1R15A" "NR4A2"    "CYTB"     "RNR2"     "COX2"
# [19] "ND4L"     "IER2"     "ZFP36L2"  "COX3"     "CXCR4"    "BTG2"
# [25] "ATP6"     "H3F3B"    "ND1"      "EGR1"     "CCL4"     "NR4A1"
#
# $cGEP12
#  [1] "TotalSeqC0954" "LOC100996919"  "NKG7"          "GZMH"
#  [5] "TotalseqC0252" "GZMA"          "CCL5"          "ACTB"
#  [9] "PFN1"          "SH3BGRL3"      "TMSB4X"        "LOC100996809"
# [13] "CFL1"          "LOC101060038"  "CORO1A"        "PLAAT4"
# [17] "HCST"          "HLA-DPA1"      "CLIC1"         "ACTG1"
# [21] "HLA-DRB1"      "HLA-DPB1"      "B2M"           "HLA-C"
# [25] "CD8A"          "GZMB"          "IL32"          "LOC102723461"
# [29] "CST7"          "CD3D"
#
# $cGEP13
#  [1] "LYZ"           "LINC01272"     "S100A9"        "LOC100130520"
#  [5] "FCN1"          "CST3"          "S100A8"        "SERPINA1"
#  [9] "SPI1"          "TYROBP"        "CSTA"          "VCAN"
# [13] "CYBB"          "FPR1"          "CD14"          "LOC100507639"
# [17] "MAFB"          "TNFAIP2"       "MNDA"          "CLEC7A"
# [21] "TMEM176B"      "RP11-1143G9.4" "LOC102723715"  "CXCL8"
# [25] "TNFSF13"       "SLC7A7"        "LILRB2"        "CSF3R"
# [29] "LILRB4"        "RBP7"
#
# $cGEP14
#  [1] "HLA-DRA"    "CD74"       "CD79A"      "AL096701.2" "MS4A1"
#  [6] "VPREB1"     "BANK1"      "MEF2C"      "TCL1A"      "VPREB3"
# [11] "HLA-DPA1"   "CD22"       "HNRNPA1P32" "HLA-DRB1"   "HLA-DQA1"
# [16] "HLA-DQB1"   "HMGB1P13"   "CD79B"      "NAPSB"      "MARCH1"
# [21] "AL121821.2" "HLA-DPB1"   "HLA-DRB6"   "ARHGAP24"   "SPIB"
# [26] "CD19"       "RALGPS2"    "CD24"       "SWAP70"     "FCER2"
#
# $cGEP15
#  [1] "RP11.295G20.2"  "CPEB1.AS1"      "RPL27A"         "CTD.2012K14.8"
#  [5] "RPL31"          "RPS17"          "RPL13A"         "SCGB3A2"
#  [9] "RPS29"          "RPL21"          "SGMS1.AS1"      "SFTPC"
# [13] "RP11.378A13.2"  "RP11-347P5.1"   "RPS20"          "RPLP2"
# [17] "RPL7"           "CCL18"          "RPS10"          "RPS27"
# [21] "MALAT1"         "ATP5EP2"        "RPL26"          "TMSB4X"
# [25] "RPL23A"         "RPL41"          "FABP4"          "MARCO"
# [29] "RPL36A"         "RP5.1042K10.10"
#
# $cGEP16
#  [1] "ONECUT2" "DMBT1"   "KRT20"   "HRCT1"   "ALDOB"   "OLFM4"   "MEP1A"
#  [8] "FABP2"   "EPCAM"   "TRIM54"  "TRAV9-2" "CD52"    "HLA-C"   "A1CF"
# [15] "FAM3D"   "S100A14" "AKR7A3"  "SI"      "CLRN3"   "B2M"     "CX3CR1"
# [22] "HAAO"    "S100A4"  "TM6SF2"  "GDF15"   "PART1"   "CCL25"   "TRAC"
# [29] "TBX3"    "GP2"
#
# $cGEP17
#  [1] "RP11-354E11.2" "CRISPLD1"      "NTM"           "HDC"
#  [5] "GNLY"          "TYROBP"        "XCL1"          "XCL2"
#  [9] "FCER1G"        "SPTSSB"        "KLRC1"         "ALKAL2"
# [13] "RP11-245G13.2" "CPA3"          "CTD-2165H16.3" "PPM1H"
# [17] "TPSB2"         "TNFRSF18"      "KLRF1"         "IFITM3"
# [21] "KIR2DL4"       "IL2RB"         "SELL"          "IGFBP7"
# [25] "CTSW"          "NCAM1"         "CAPG"          "FLJ21408"
# [29] "DACH1"         "CNRIP1"
#
# $cGEP18
#  [1] "CPA3"          "TPSAB1"        "TPSB2"         "AP000781.2"
#  [5] "MS4A2"         "HPGDS"         "SLC18A2"       "RP11-354E11.2"
#  [9] "GATA2"         "AC004791.2"    "HDC"           "CTSG"
# [13] "KIT"           "AL157895.1"    "TMEM220-AS1"   "MBL1P"
# [17] "FLJ40194"      "RP11-76E17.3"  "RHEX"          "ADCYAP1"
# [21] "AL731557.1"    "AC015689.2"    "HPGD"          "SLC45A3"
# [25] "RPS23P6"       "IL1RL1"        "TPSD1"         "AC046143.2"
# [29] "RGS13"         "LTC4S"
#
# $cGEP19
#  [1] "TNFRSF18"   "FOXP3"      "TNFRSF4"    "IL2RA"      "LINC01943"
#  [6] "BATF"       "CTLA4"      "HNRNPA1P21" "TIGIT"      "IL1R2"
# [11] "TBC1D4"     "IL32"       "AL034345.2" "AC017002.3" "LAYN"
# [16] "DNPH1"      "CARD16"     "ICOS"       "LAIR2"      "PKM"
# [21] "S100A4"     "MAGEH1"     "CCR8"       "CD177"      "TNFRSF1B"
# [26] "TNFRSF9"    "FANK1"      "RTKN2"      "CORO1B"     "CD27"
#
# $cGEP20
#  [1] "TotalSeqC0951" "CCL5"          "CCL4"          "NKG7"
#  [5] "CST7"          "DUSP2"         "TRBV7-9"       "CCL4L2"
#  [9] "CD8A"          "TRBV7-4"       "GZMA"          "GZMH"
# [13] "CRTAM"         "CMC1"          "TRBV7-2"       "HLA-DRB1"
# [17] "CXCR4"         "GZMK"          "CCL3"          "HLA-A"
# [21] "CEMIP2"        "CD160"         "PIK3R1"        "FYN"
# [25] "GZMM"          "APOBEC3G"      "TUBA4A"        "CD74"
# [29] "PTPRC"         "HCST"
#
# $cGEP21
#  [1] "UBE2C"    "C15ORF53" "RRM2"     "TOP2A"    "STMN1"    "PCLAF"
#  [7] "TUBA1B"   "TUBB"     "MKI67"    "BIRC5"    "AURKB"    "DLGAP5"
# [13] "HJURP"    "TYMS"     "HIST1H4C" "PLK1"     "NUSAP1"   "ASPM"
# [19] "CCNB2"    "CCNA2"    "CDCA5"    "GTSE1"    "HMGB2"    "KIF2C"
# [25] "TPX2"     "CENPF"    "CDK1"     "SPC25"    "KIFC1"    "KIF15"
#
# $cGEP22
#  [1] "HAVCR2"       "PRF1"         "AC069363.1"   "CTLA4"        "LAG3"
#  [6] "VCAM1"        "CST7"         "SNAP47"       "HMOX1"        "LYST"
# [11] "AC243829.4"   "FAM3C"        "CADM1"        "SNX9"         "TNIP3"
# [16] "IGFLR1"       "PTMS"         "CBLB"         "RDH10"        "AD000671.6"
# [21] "DUSP4"        "TNFRSF9"      "RP11-492E3.2" "CD7"          "TIGIT"
# [26] "PHLDA1"       "LAYN"         "SHFM1"        "ADGRG1"       "TGIF1"
#
# $cGEP23
#  [1] "TMSB4XP4" "ACTB"     "S100A4"   "PFN1"     "CD52"     "ACTG1"
#  [7] "TMSB4X"   "SH3BGRL3" "IL32"     "S100A6"   "VIM"      "S100A11"
# [13] "LGALS1"   "S100A10"  "GAPDH"    "CFL1"     "TMSB10"   "ARPC1B"
# [19] "MYL6"     "CORO1A"   "ANXA2"    "COTL1"    "CLIC1"    "LTB"
# [25] "CRIP1"    "EMP3"     "MYL12A"   "KRT84"    "RAC2"     "ARHGDIB"
#
# $cGEP24
#  [1] "IGHV1-69-2"   "RP11-16E12.2" "IGKV1OR2-108" "IGHV5-10-1"   "IGHV1-69"
#  [6] "IGHG1"        "IGKC"         "MZB1"         "DERL3"        "JCHAIN"
# [11] "IGHG3"        "IGHG4"        "IGLV2-14"     "IGHG2"        "IGKV1-39"
# [16] "IGHV4-59"     "IGHGP"        "IGKV1D-33"    "FCRL5"        "IGLC2"
# [21] "TNFRSF17"     "IGLV6-57"     "IGKV1-6"      "IGHA1"        "IGKV1D-39"
# [26] "IGKV1-16"     "IGKV3D-15"    "IGLV9-49"     "AC104971.3"   "AC104699.1"
#
# $cGEP25
#  [1] "RACK1"   "ATP5F1E" "ATP5MG"  "FYB1"    "NOP53"   "ATP5MC2" "RIPOR2"
#  [8] "TRIR"    "ELOB"    "ATP5MD"  "ATP5ME"  "ATP5IF1" "ATP5MPL" "ATP5MC3"
# [15] "MT-CYB"  "NSD3"    "PAXX"    "ATP5F1B" "ATP5PF"  "ATP5MF"  "SELENOW"
# [22] "ATP5F1A" "SELENOH" "COPS9"   "ATP5PB"  "ATP5PD"  "TXNIP"   "MT-ND3"
# [29] "SELENOF" "OGA"
#
# $cGEP26
#  [1] "HLA-DQA1"     "HLA-DRB5"     "HLA-DRB1"     "CD74"         "HLA-DRA"
#  [6] "AP003557.1"   "FXYD6"        "HLA-DQA2"     "HLA-DPA1"     "CXCL13"
# [11] "HLA-DQB1"     "CLDN16"       "PDLIM4"       "HLA-DPB1"     "CRTAM"
# [16] "RASSF4"       "UNQ6494"      "MIR155HG"     "PKM"          "TNFRSF9"
# [21] "LHFPL6"       "CAV1"         "MYOD1"        "PON3"         "MS4A6A"
# [26] "RP11-655C2.3" "CD82"         "ZADH2"        "HOXB8"        "GUCY1B1"
#
# $cGEP27
#  [1] "AC245427.1"   "NKG7"         "FCGR3A"       "PRF1"         "GPR56"
#  [6] "FGFBP2"       "KLRF1"        "GNLY"         "TYROBP"       "SPON2"
# [11] "GZMB"         "KLRD1"        "FCER1G"       "CTSW"         "S1PR5"
# [16] "CST7"         "PLAC8"        "LOC101928429" "CX3CR1"       "CLIC3"
# [21] "SH2D1B"       "ITGB2"        "FGR"          "AKR1C3"       "ADGRG1"
# [26] "CD247"        "PLEK"         "HOPX"         "LOC101060789" "TRDC"
#
# $cGEP28
#  [1] "FXYD2"        "TMEM155"      "TNFRSF9"      "CD27"         "CCL4L2"
#  [6] "LOC100129931" "CCL3L3"       "TRAV19"       "TNS3"         "GZMK"
# [11] "ETV1"         "CCL3"         "XCL1"         "CD82"         "HSPA12A"
# [16] "VCAM1"        "EMR1"         "MIR155HG"     "GEM"          "TTN"
# [21] "DSCAML1"      "NR5A2"        "CCL4"         "LOC101928983" "EGR2"
# [26] "AL391056.1"   "LYST"         "DUSP4"        "XCL2"         "LINC00158"
#
# $cGEP29
#  [1] "RPS15A"     "GZMK"       "RARRES3"    "RPL28"      "RPS27"
#  [6] "RPL7A"      "RPL23A"     "ATP5E"      "RPS7"       "CMC1"
# [11] "CST7"       "RPS24"      "RPL30"      "RPS15"      "RPS25"
# [16] "AL627171.2" "GNB2L1"     "RPL10"      "RPL13"      "NKG7"
# [21] "GIMAP4"     "RPS28"      "ATP5G2"     "RPS12"      "RPL35A"
# [26] "RPS14"      "ATP5L"      "RPL39"      "RPL36"      "CCL5"
#
# $cGEP30
#  [1] "ATP8"          "MALAT1"        "ATP6"          "ND4"
#  [5] "ND4L"          "CYTB"          "ND2"           "COX1"
#  [9] "ND3"           "RNR2"          "ND1"           "COX3"
# [13] "ND6"           "ND5"           "PTPRC"         "RNR1"
# [17] "RP11-463O12.5" "NEAT1"         "MT-ATP6"       "MT-ND3"
# [21] "DDX17"         "SYNE2"         "NKTR"          "MT-RNR1"
# [25] "KIAA1551"      "MBNL1"         "RPL5P4"        "MT-ND5"
# [29] "COX2"          "MT-ND2"
#
# $cGEP31
#  [1] "AIM1"         "IL7R"         "TXNIP"        "SMIM3"        "TSC22D3"
#  [6] "ND5"          "AC007349.2"   "CRYBG1"       "CD97"         "GPR171"
# [11] "PARP8"        "FKBP5"        "PTGER4"       "ATP6"         "TNFAIP3"
# [16] "TPT1"         "RPLP1"        "PRDM1"        "ZFP36L2"      "PFKFB3"
# [21] "ZFP36"        "LOC101060038" "ID2"          "RNR1"         "KLF6"
# [26] "NFKBIA"       "ITGA1"        "ND6"          "ND3"          "CD96"
#
# $cGEP32
#  [1] "HLA-DRB4"     "LOC100996809" "CD74"         "COTL1"        "TRBV11-3"
#  [6] "HLA-DRB1"     "CD27"         "HLA-DRA"      "LOC101929876" "LOC101928173"
# [11] "HLA-DPA1"     "TRBV5-5"      "ACTG1"        "ACTB"         "HLA-DPB1"
# [16] "HLA-DRB3"     "AC007993.3"   "GAPDH"        "GZMK"         "HLA-DQA1"
# [21] "FABP5"        "HLA-DQB1"     "TIGIT"        "ITM2A"        "PFN1"
# [26] "GZMA"         "HLA-DMA"      "PCAT29"       "TRAC"         "CXCL13"
#
# $cGEP33
#  [1] "DUSP1"    "HSPA1B"   "DNAJB1"   "NR4A1"    "PPP1R15A" "GADD45B"
#  [7] "JUN"      "ACTB"     "NFKBIA"   "HSPA1A"   "TNF"      "CD69"
# [13] "JUNB"     "IFNG"     "DNAJB4"   "FOS"      "BTG2"     "SGK1"
# [19] "DDIT4"    "HSPA6"    "RHOB"     "FOSB"     "ATF3"     "IER3"
# [25] "IER2"     "TNFSF9"   "ACTG1"    "HSPA2"    "NR4A2"    "RGS16"
#
# $cGEP34
#  [1] "8h.2"          "24h.2"         "BRE-AS1"       "RP11-631M6.2"
#  [5] "FTH1P10"       "CREM"          "CXCR4"         "SRGN"
#  [9] "ZFP36L2"       "RP11-463O12.5" "YPEL5"         "BTG1"
# [13] "ZFP36"         "LOC101929876"  "ZNF331"        "EIF1"
# [17] "NR4A2"         "6h.2"          "TNFAIP3"       "FTH1"
# [21] "DUSP2"         "TUBA4A"        "COX7BP2"       "PIK3R1"
# [25] "FAM177A1"      "SARAF"         "H3F3B"         "SRSF2"
# [29] "MCL1"          "EZR"
#
# $cGEP35
#  [1] "LAG3"      "CD27"      "GZMK"      "CMC1"      "CADM1"     "HMOX1"
#  [7] "IFI6"      "ISG20"     "CST7"      "FXYD2"     "LINC01943" "DUSP2"
# [13] "ISG15"     "MX1"       "TIMD4"     "RGS1"      "TIGIT"     "SIRPG"
# [19] "HLA-B"     "NKG7"      "DENND2D"   "DUSP4"     "ADTRP"     "CEMIP2"
# [25] "PRF1"      "HLA-A"     "SEM1"      "CNN2"      "PTPRCAP"   "HAVCR2"
#
# $cGEP36
#  [1] "RPS2"   "RPL13"  "RPS12"  "RPS18"  "RPL10A" "RPS14"  "RPL32"  "RPS4X"
#  [9] "RPL10"  "RPS27A" "RPLP1"  "EEF1A1" "EEF1B2" "RPS23"  "RPS3A"  "RPL18"
# [17] "RPL12"  "RPL29"  "RPS5"   "RPS8"   "RPL19"  "24h"    "RPSA"   "4h"
# [25] "8h"     "RPS6"   "6h"     "RPL30"  "RPS3"   "RPL11"
#
# $cGEP37
#  [1] "AC053545.1" "PCLAF"      "TYMS"       "MOGAT2"     "RRM2"
#  [6] "TK1"        "STMN1"      "TUBB"       "TUBA1B"     "KIAA0101"
# [11] "DUT"        "HMGN2"      "GINS2"      "UHRF1"      "MCM7"
# [16] "ZWINT"      "CDT1"       "PPIA"       "ACTB"       "SEPTIN5"
# [21] "GAPDH"      "PKMYT1"     "PFN1"       "ASF1B"      "CDC45"
# [26] "ACTG1"      "CDCA5"      "PCNA"       "MYBL2"      "CLSPN"
#
# $cGEP38
#  [1] "KRT75"      "KCNK10"     "MIR205HG"   "KRT31"      "BPIFC"
#  [6] "KRT6A"      "KRT14"      "S100A9"     "KRT16"      "S100A8"
# [11] "KRT5"       "KRT6B"      "S100A2"     "CLEC2A"     "MIR200CHG"
# [16] "FABP7"      "LY6D"       "KRT6C"      "EPB41L4B"   "SFN"
# [21] "GJB2"       "PERP"       "TACSTD2"    "S100A14"    "GJB4"
# [26] "KRT17"      "PPP1R1C"    "S100A16"    "AL033384.1" "RAB17"
#
# $cGEP39
#  [1] "CST6"       "C1QC"       "C1QB"       "CST3"       "C1QA"
#  [6] "APOE"       "APOC1"      "FCER1G"     "KIAA1598"   "HLA-DRA"
# [11] "SELENOP"    "LYZ"        "MAFB"       "C3"         "TYROBP"
# [16] "CSF1R"      "CYBB"       "CD74"       "HLA-DPA1"   "CD68"
# [21] "MS4A6A"     "IL18"       "TMEM176B"   "SPI1"       "FTL"
# [26] "FOLR2"      "AC243772.2" "CD14"       "RNASE1"     "IGSF6"
#
# $cGEP40
#  [1] "TYROBP"       "LOC101060038" "KLRC1"        "KRT81"        "KRT86"
#  [6] "GNLY"         "KIR2DL4"      "FCER1G"       "CD7"          "LAT2"
# [11] "TRDC"         "ADGRG3"       "B3GNT7"       "KLRC2"        "HOPX"
# [16] "SH2D1B"       "IL2RB"        "KLRD1"        "TNFRSF18"     "TMIGD2"
# [21] "AC012414.3"   "CTSW"         "HLA-H"        "ZNF683"       "CCL5"
# [26] "CD63"         "CXXC5"        "KLRC3"        "MATK"         "AC092580.4"
#
# $cGEP41
#  [1] "SESN3"        "CTB-133G6.1"  "SELL"         "ASCL1"        "PASK"
#  [6] "SPON1"        "LHFPL6"       "TSHZ2"        "GLTSCR2"      "IGFL2"
# [11] "RPS8"         "CCR7"         "FKBP5"        "NR3C1"        "RPL11"
# [16] "IL6ST"        "LEF1"         "CYSLTR1"      "FAM65B"       "AC004585.1"
# [21] "MAL"          "NMB"          "AJ009632.2"   "TCF7"         "GNB2L1"
# [26] "CPM"          "METTL8"       "RP11-712B9.2" "RPL37"        "RPL39"
#
# $cGEP42
#  [1] "CSN3"          "RPL13A"        "FDCSP"         "RPL27A"
#  [5] "MALAT1"        "ITM2C"         "SMR3B"         "ZG16B"
#  [9] "SLPI"          "RPS20"         "PCED1B-AS1"    "RPS2"
# [13] "TMSB4X"        "C2ORF82"       "RPS26"         "AQP5"
# [17] "RPS19"         "KIAA1551"      "RP11-18H21.1"  "TPT1"
# [21] "RP11-291B21.2" "XIST"          "RPL37A"        "PNRC1"
# [25] "C12ORF75"      "MYH9"          "RPS16"         "CPNE7"
# [29] "RPL13"         "RPL23"
#
# $cGEP43
#  [1] "ASIP"      "LILRA4"    "PTGDS"     "PLD4"      "IL3RA"     "IRF8"
#  [7] "FLT3"      "IRF7"      "DNASE1L3"  "GZMB"      "SERPINF1"  "SLC32A1"
# [13] "SMIM5"     "LAMP5"     "RGS2"      "PPP1R14B"  "LRRC26"    "CLEC4C"
# [19] "DERL3"     "TCF4"      "LINC00996" "SPIB"      "KCNK17"    "PLAC8"
# [25] "TCL1A"     "CYP46A1"   "FCER1G"    "EGLN3"     "C12orf75"  "SOX4"
#
# $cGEP44
#  [1] "RAB5IF"   "SRGN"     "CST7"     "CREM"     "NKG7"     "FTH1"
#  [7] "RPS26"    "LITAF"    "CXCR4"    "FYN"      "RPL10"    "RPS3"
# [13] "SARAF"    "PIK3R1"   "DUSP2"    "C1ORF21"  "RPL23A"   "GZMM"
# [19] "BTG1"     "HLA-B"    "RPS15A"   "FGFBP2"   "LEPROTL1" "MT1G"
# [25] "SH2D2A"   "SYAP1"    "RPL3"     "SYTL3"    "ATP5MPL"  "FAM177A1"
#
# $cGEP45
#  [1] "METRNL"     "SLC7A5"     "CREM"       "FOSL2"      "GABARAPL1"
#  [6] "ZFP36L2"    "LINC02446"  "AC020916.1" "RUNX3"      "ATP1B3"
# [11] "CCL5"       "CCL4"       "JUND"       "TENT5C"     "KLRC1"
# [16] "SRGN"       "BTG1"       "AC092580.4" "PTPN22"     "AUTS2"
# [21] "LINC01871"  "RANBP2"     "SYTL3"      "TGFB1"      "ITGAD"
# [26] "RNF125"     "PGK1"       "CD8A"       "PARD6G"     "CD7"
#
# $cGEP46
#  [1] "LMNA"          "VIM"           "MYADM"         "TAGLN2"
#  [5] "S100A10"       "ADGRE5"        "S100A11"       "CRIP1"
#  [9] "RGCC"          "ANXA1"         "RP11-124N14.3" "CRIP2"
# [13] "AHNAK"         "ANXA2"         "CD44"          "GPAT3"
# [17] "EZR"           "MT-ND2"        "LRRFIP1"       "GPR183"
# [21] "CTD-3252C9.4"  "MT-ND1"        "AL022718.1"    "AAED1"
# [25] "RPL23AP42"     "IDS"           "AC016739.1"    "IL7R"
# [29] "AL590867.2"    "KLF6"
#
# $cGEP47
#  [1] "COL1A1"   "MT-ATP6"  "MT-CYB"   "RARRES2"  "MT-CO3"   "MT-ND1"
#  [7] "MT-CO1"   "MT-ND4"   "MT-CO2"   "TIMP3"    "BGN"      "LUM"
# [13] "MT-ND2"   "LGALS1"   "MT-ND3"   "COMP"     "MT-ND5"   "FN1"
# [19] "MYL9"     "MT-ND4L"  "DCN"      "SFRP2"    "COL1A2"   "CXCL14"
# [25] "INHBA"    "NNMT"     "UBE2L5P"  "CHRDL2"   "ATP5F1"   "MTRNR2L8"
#
# $cGEP48
#  [1] "TFF2"       "CA9"        "FXYD4"      "DNAH3"      "AC106900.2"
#  [6] "KRT13"      "KRT19"      "GP2"        "S100A6"     "AGR2"
# [11] "IFI27"      "WFDC2"      "SOX21-AS1"  "LINC01843"  "KRT8"
# [16] "CRYBA2"     "FXYD3"      "KISS1"      "CXCL17"     "LYZ"
# [21] "LINC00261"  "LGALS4"     "MAB21L4"    "CNNM1"      "EPCAM"
# [26] "S100A14"    "AC010745.1" "CST3"       "TFF1"       "LINC02182"
#
# $cGEP49
#  [1] "KLRB1"     "CTSH"      "S100A4"    "IL26"      "CCR6"      "S100A6"
#  [7] "SPOCK2"    "LGALS3"    "FURIN"     "PTPN13"    "CAPG"      "JAML"
# [13] "ADAM12"    "CD40LG"    "SLC1A4"    "RORA"      "PKIG"      "TNFRSF25"
# [19] "OSTF1"     "ALOX5AP"   "CXCR6"     "AHR"       "LMO4"      "ADAM19"
# [25] "SH3BGRL3"  "NBAS"      "BATF"      "GNA15"     "KDSR"      "C10orf128"
#
# $cGEP50
#  [1] "VIM"       "CRIP1"     "GATA3"     "S100A4"    "LTB"       "S100A10"
#  [7] "ANXA1"     "HIST1H4C"  "LGALS1"    "PLP2"      "SEMA3G"    "ANXA2"
# [13] "LMNA"      "KRT1"      "RPL13AP20" "SEMA5A"    "S100A6"    "BIRC3"
# [19] "SPC25"     "AHNAK"     "ANXA2P3"   "S100A11"   "MAP3K1"    "ARID5B"
# [25] "CCR10"     "TOB1"      "TSHR"      "IL7R"      "ITGB1"     "CRIP2"
#
# $cGEP51
#  [1] "KRT7"       "LINC01681"  "SPATA22"    "SLPI"       "TMC5"
#  [6] "PADI2"      "SALL2"      "S100A2"     "FXYD3"      "S100A9"
# [11] "LMO1"       "KRT17"      "MGST1"      "LCN2"       "MTND2P28"
# [16] "S100A11"    "MEI4"       "CP"         "SFN"        "TSPAN1"
# [21] "AGR2"       "PRSS2"      "TACSTD2"    "TFF3"       "AC139143.1"
# [26] "SERPINB3"   "SOWAHB"     "S100A16"    "SLC34A2"    "SFTPB"
#
# $cGEP52
#  [1] "AC020916.1" "HLA-DRB1"   "HLA-DRA"    "HLA-DRB5"   "PRMT9"
#  [6] "CCL5"       "CD74"       "GZMA"       "GNLY"       "ZNF683"
# [11] "TMSB4X"     "HLA-DPA1"   "CYTOR"      "ITGB1"      "TRG-AS1"
# [16] "HLA-DPB1"   "HLA-DQA1"   "KRT86"      "ITGA1"      "KIR2DL1"
# [21] "CCL3"       "CCL4"       "KIR2DS4"    "CD63"       "AC114760.2"
# [26] "ITM2C"      "CCL3L1"     "CTSW"       "AL627171.1" "TBCD"
#
# $cGEP53
#  [1] "FTL"     "PSAP"    "CD68"    "SAT1"    "FTH1"    "TYROBP"  "LILRB2"
#  [8] "FCER1G"  "PLAUR"   "APOE"    "S100A11" "LST1"    "CXCL16"  "APOC1"
# [15] "SMIM25"  "NPC2"    "AIF1"    "C5AR1"   "CST3"    "CLEC7A"  "LRRC25"
# [22] "SPI1"    "TIMP1"   "ASAH1"   "FCN1"    "LILRA5"  "LGALS1"  "HLA-DRA"
# [29] "GRN"     "CTSD"
#
# $cGEP54
#  [1] "FAM3B"      "CST3"       "LYZ"        "CPVL"       "HLA-DRA"
#  [6] "HLA-DPB1"   "CLEC9A"     "HLA-DPA1"   "NAPSA"      "DCLK2"
# [11] "CD74"       "SPI1"       "AC096667.1" "HLA-DQA1"   "HLA-DRB1"
# [16] "HLA-DRB5"   "HCK"        "LGALS2"     "C1orf54"    "IDO1"
# [21] "WDFY4"      "HLA-DQB1"   "ZNF366"     "MPEG1"      "DNASE1L3"
# [26] "RAB32"      "C15orf48"   "CDC25C"     "HIPK4"      "KIAA0226L"
#
# $cGEP55
#  [1] "TRBV12-4"      "NRIP3"         "RASL10A"       "RP11-522I20.3"
#  [5] "PTPN3"         "NPW"           "ATP5G3"        "HMGA1"
#  [9] "ST8SIA3"       "CD81"          "FXYD2"         "CHAC1"
# [13] "CCNA2"         "SMCO4"         "FABP5"         "HN1"
# [17] "FST"           "ZNF704"        "KITLG"         "PLK1"
# [21] "SH3BP4"        "LGALS3"        "EFNA1"         "SKA1"
# [25] "HES1"          "ESPL1"         "STAC3"         "MYO7B"
# [29] "SGOL2"         "IL10"
#
# $cGEP56
#  [1] "AC253572.1" "CDC25C"     "KIF14"      "HN1"        "KIF15"
#  [6] "MTFR2"      "KIAA0101"   "TUBA1B"     "FGGY"       "DEPDC1"
# [11] "HNRNPA1P48" "UBE2C"      "HMGB2"      "CKS2"       "TPX2"
# [16] "TMSB4X"     "PTTG1"      "AC009299.3" "ISG15"      "HMMR"
# [21] "MND1"       "TOP2A"      "PFN1"       "CFL1"       "BIRC5"
# [26] "CENPE"      "TUBB"       "CCNB2"      "CKS1B"      "SGOL1"
#
# $cGEP57
#  [1] "MT-ATP6"    "MT-CO2"     "JUND"       "MT-CYB"     "MT-ND4"
#  [6] "MT-CO3"     "MT-CO1"     "NEAT1"      "ARL4C"      "MT-ND3"
# [11] "MT-ND1"     "LINC00513"  "MT-ND5"     "TNFAIP3"    "CALM1"
# [16] "NCL"        "HSP90AB1"   "LCP1"       "KLK3"       "AC020916.1"
# [21] "DDX24"      "CD81"       "MT-ND4L"    "CRYBG1"     "KLK2"
# [26] "MBNL1"      "HNRNPAB"    "GRK2"       "METRNL"     "MT-ND6"
#
# $cGEP58
#  [1] "AK4"     "DNTT"    "LDHA"    "ENO1"    "PKM"     "IL9R"    "MIF"
#  [8] "PGK1"    "MYC"     "ALDOA"   "TAGLN2"  "IL32"    "RPLP0"   "LDHB"
# [15] "TPI1"    "PIM1"    "PABPC1"  "GAPDH"   "SOCS3"   "HSPA8"   "CISH"
# [22] "IL17RB"  "GPI"     "CSF2"    "TMEM123" "EEF2"    "SELL"    "LTB"
# [29] "PIM2"    "PGAM1"
#
# $cGEP59
#  [1] "GZMB"          "CD7"           "GNLY"          "CRX"
#  [5] "SPINK2"        "KLRD1"         "CAPG"          "LGALS1"
#  [9] "LRRC34"        "KLRC1"         "RP11-291B21.2" "RP11-356J5.12"
# [13] "PGK1"          "LGALS3"        "CD63"          "PLEKHA6"
# [17] "PRF1"          "ADAMTS2"       "VIM"           "HOPX"
# [21] "GAPDH"         "IL12RB2"       "GPR25"         "IFITM2"
# [25] "LRAT"          "XCL1"          "CTSA"          "S100A6"
# [29] "GLUL"          "RP11-305L7.1"
#
# $cGEP60
#  [1] "AKR1B10"    "MRAP2"      "CXCL5"      "RAET1L"     "HOXC8"
#  [6] "TLCD2"      "CRCT1"      "PLA2G4F"    "LCN2"       "VSTM5"
# [11] "S100P"      "KLK13"      "LINC00973"  "ESRP1"      "LINC01612"
# [16] "LY6K"       "EVA1A"      "TFF1"       "SPINK1"     "LINP1"
# [21] "KRT18"      "KRT8"       "KRT13"      "FRAS1"      "MT1G"
# [26] "SLPI"       "TSPAN8"     "GPX2"       "AL365356.5" "SIX4"
#
# $cGEP61
#  [1] "COL3A1"  "POSTN"   "COL1A1"  "COL1A2"  "COL6A1"  "COL6A3"  "CAPN6"
#  [8] "LUM"     "SGCD"    "DCN"     "COL6A2"  "OAF"     "ANGPT1"  "BOC"
# [15] "ADGRA2"  "SEZ6L2"  "LHFPL2"  "EMILIN1" "SPARC"   "DLK1"    "IGF2"
# [22] "RUNX1T1" "EGFR"    "TMEM130" "NR2F1"   "DCX"     "GAS1"    "PALM"
# [29] "COL4A1"  "MGP"
#
# $cGEP62
#  [1] "CD7"          "KLRC2"        "KRT81"        "KRT86"        "KLRC3"
#  [6] "LOC101060038" "ZNF683"       "CD9"          "ND4L"         "CTSW"
# [11] "XCL1"         "TXK"          "KLRD1"        "CAPG"         "ND1"
# [16] "SRGAP3"       "LINC02446"    "AMICA1"       "KIR3DL2"      "CYTB"
# [21] "ND2"          "SPRY2"        "SPINT2"       "HOPX"         "IL2"
# [26] "NCR3"         "CD69"         "ND4"          "LILRP2"       "EPAS1"
#
# $cGEP63
#  [1] "LINC01297"     "STON1"         "SLC52A3"       "FGFR3"
#  [5] "MSMB"          "SLC2A5"        "PPARGC1A"      "AGR2"
#  [9] "VANGL2"        "PDLIM3"        "RP11-115D19.1" "MACROD2"
# [13] "ARHGAP6"       "WNT4"          "KLK2"          "ZNF350-AS1"
# [17] "MOGAT2"        "CDK14"         "CDC42EP5"      "ACPP"
# [21] "PRRG1"         "CCK"           "PLS3"          "CADPS2"
# [25] "VEGFA"         "IRX4"          "CLDN11"        "ORM1"
# [29] "ACSS3"         "KLK3"
#
# $cGEP64
#  [1] "SFTPC"      "SFTPA2"     "SFTPA1"     "SCGB3A2"    "KRT8"
#  [6] "FTH1"       "AL162511.1" "KRT18"      "LINC01986"  "RPL7"
# [11] "RPS4X"      "NFKBIA"     "CXCL2"      "RPLP0"      "SFTPB"
# [16] "MMP7"       "RPL3"       "RPSA"       "ACTB"       "SPINT2"
# [21] "B2M"        "LCN2"       "MDK"        "RPS6"       "CD9"
# [26] "HLA-DRB1"   "JUNB"       "RACK1"      "ELF3"       "LDHB"
#
# $cGEP65
#  [1] "TPSAB1"        "CNRIP1"        "GATA2"         "RP11-354E11.2"
#  [5] "PRSS57"        "PNMT"          "HPGDS"         "MS4A2"
#  [9] "CPA3"          "TPSB2"         "RUNDC3A"       "DPP10"
# [13] "RASGRP4"       "KRT1"          "SVOPL"         "TK1"
# [17] "KEL"           "EFHC2"         "GVQW1"         "KIAA0101"
# [21] "TYMS"          "TPSD1"         "LGALS12"       "DHRS9"
# [25] "GLUL"          "CXCL2"         "PDE6G"         "EXD3"
# [29] "PHACTR1"       "EMID1"
#
# $cGEP66
#  [1] "MTRNR2L8"   "RPS4Y1"     "DDX3Y"      "H3F3B"      "MALAT1"
#  [6] "CCNL1"      "NR4A2"      "SRSF7"      "CLK1"       "EIF1"
# [11] "RBM39"      "JUN"        "UTY"        "TTTY15"     "SBDS"
# [16] "SRSF5"      "AC245014.3" "BTG1"       "HSPA5"      "DDX24"
# [21] "HLA-B"      "HIST1H1E"   "MIDN"       "SSBP3"      "H1FX"
# [26] "RPL27A"     "IFRD1"      "ITGAM"      "TRA2B"      "YPEL5"
#
# $cGEP67
#  [1] "LINC01531"     "SEMA3B"        "PANK1"         "GPR37"
#  [5] "ADSSL1"        "RP11-176H8.1"  "EMILIN1"       "LINC00839"
#  [9] "S100A1"        "ZNF202"        "HSPB2"         "ADIRF"
# [13] "VN1R1"         "SMO"           "FABP3"         "ECHDC3"
# [17] "PPP1R3C"       "CKMT2-AS1"     "TM4SF4"        "PCSK4"
# [21] "PRDM5"         "GSTP1"         "RP11-172H24.4" "GPX3"
# [25] "PPFIBP2"       "S100A16"       "SOD3"          "S100A14"
# [29] "GAS1"          "PKIB"
#
# $cGEP68
#  [1] "HLA-H"    "CYTB"     "ND4"      "HLA-A"    "ND4L"     "ATP6"
#  [7] "ATP8"     "ND2"      "ND1"      "NKG7"     "RNR2"     "FGFBP2"
# [13] "GZMH"     "COX2"     "ND3"      "S100A4"   "COX1"     "LGALS1"
# [19] "SH3BGRL3" "ACTB"     "PFN1"     "CTSW"     "GZMB"     "CD8A"
# [25] "ITGB2"    "HLA-DRB5" "COX3"     "ND5"      "FCGR3A"   "GNLY"
#
# $cGEP69
#  [1] "IGHGP"    "ID4"      "LY6K"     "TUBB"     "RPS20"    "RPL29"
#  [7] "RAB13"    "TM4SF1"   "EEF1A1"   "HES1"     "C1QB"     "TPPP3"
# [13] "RPL35A"   "MT-ND1"   "RPL8"     "HSP90AB1" "RPS8"     "PSAT1"
# [19] "RPL7"     "PCP4"     "SNCG"     "RPL12"    "PART1"    "HSPA6"
# [25] "IGKC"     "RPS18"    "SELENBP1" "IGLC7"    "RBP1"     "RPL31"
#
# $cGEP70
#  [1] "AFF3"          "ZFP41"         "MT.ND3"        "BEND6"
#  [5] "EVI5"          "PLEKHG6"       "UBD"           "MT.ND2"
#  [9] "C2orf88"       "BHLHB9"        "RNU12"         "CTSK"
# [13] "C16orf59"      "SLC44A3"       "MT.ND1"        "OSBPL10.AS1"
# [17] "RALY.AS1"      "COL17A1"       "CTA.221G9.12"  "RP11.344P13.6"
# [21] "MT.CO3"        "RP11.102N12.3" "RP11.297B17.3" "FCER2"
# [25] "SLC12A8"       "TM4SF1"        "MT.ATP6"       "ASAP3"
# [29] "ATP2A1"        "LA16c.306E5.2"

# %%
convert_gene <- function(gene_symbol_vector){
  bitr(gene_symbol_vector, 
       fromType = "SYMBOL",
       toType = "ENTREZID",
       OrgDb = org.Hs.eg.db) %>%
    pull(ENTREZID)
}

clean_symbol <- function(x){
  x <- unique(x)
  x <- x[x != ""]
  x <- toupper(x)
  x
}

cluster_genes <- lapply(cluster_genes, clean_symbol)

# %%
library(clusterProfiler)
library(org.Hs.eg.db)
library(ReactomePA)
library(msigdbr)
library(dplyr)

# ============================
# 清洗基因名
# ============================
clean_symbol <- function(x){
  x <- unique(toupper(x))
  x[x != ""]
}

cluster_genes <- lapply(cluster_genes, clean_symbol)

# ============================
# SYMBOL → ENTREZ 映射
# ============================
all_symbols <- unique(unlist(cluster_genes))

symbol2entrez <- bitr(all_symbols,
                      fromType="SYMBOL",
                      toType="ENTREZID",
                      OrgDb=org.Hs.eg.db)

# named vector
map_table <- symbol2entrez$ENTREZID
names(map_table) <- symbol2entrez$SYMBOL

# ============================
# MSigDB Hallmark gene sets
# ============================
msig_h <- msigdbr(species = "Homo sapiens", category = "H")

hallmark_list <- msig_h %>% 
  split(.$entrez_gene) %>%
  lapply(function(x) x$gs_name)

# ============================
# 初始化结果表
# ============================
kegg_list <- list()
go_bp_list <- list()
reactome_list <- list()
hallmark_list_results <- list()

# ============================
# 循环 70 clusters
# ============================
for(cl in names(cluster_genes)){

  message("Processing ", cl, " ...")

  # SYMBOL → ENTREZ
  genes <- cluster_genes[[cl]]
  genes_entrez <- map_table[genes]
  genes_entrez <- genes_entrez[!is.na(genes_entrez)]

  if(length(genes_entrez) < 5){
    warning(cl, ": <5 valid genes → skip")
    next
  }

  # KEGG（可以为空）
  kegg_list[[cl]] <- tryCatch({
    enrichKEGG(gene = genes_entrez, organism = "hsa",
               pvalueCutoff = 0.1)
  }, error=function(e) NULL)

  # GO BP
  go_bp_list[[cl]] <- enrichGO(gene = genes_entrez, 
                               OrgDb = org.Hs.eg.db,
                               keyType="ENTREZID",
                               ont="BP",
                               pvalueCutoff=0.1)

  # Reactome（强烈推荐）
  reactome_list[[cl]] <- enrichPathway(gene = genes_entrez,
                                       pvalueCutoff = 0.1,
                                       readable = TRUE)

  # Hallmark enrichment
  hallmark_list_results[[cl]] <- enricher(
    gene = genes_entrez,
    TERM2GENE = msig_h[,c("gs_name","entrez_gene")],
    pvalueCutoff = 0.1
  )
}
# Out:
# ReactomePA v1.42.0  For help: https://yulab-smu.top/biomedical-knowledge-mining-book/
#
# If you use ReactomePA in published research, please cite:
# Guangchuang Yu, Qing-Yu He. ReactomePA: an R/Bioconductor package for reactome pathway analysis and visualization. Molecular BioSystems 2016, 12(2):477-479
#
# 'select()' returned 1:many mapping between keys and columns
#
# Warning message in bitr(all_symbols, fromType = "SYMBOL", toType = "ENTREZID", OrgDb = org.Hs.eg.db):
# “14.31% of input gene IDs are fail to map...”
# Processing cGEP1 ...
#
# Reading KEGG annotation online: "https://rest.kegg.jp/link/hsa/pathway"...
#
# Warning message in utils::download.file(url, quiet = TRUE, method = method, ...):
# “URL 'https://rest.kegg.jp/link/hsa/pathway': Timeout of 300 seconds was reached”
# fail to download KEGG data...
#
# Processing cGEP2 ...
#
# Reading KEGG annotation online: "https://rest.kegg.jp/link/hsa/pathway"...
#
# Reading KEGG annotation online: "https://rest.kegg.jp/list/pathway"...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP3 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID: 1445,10006,26275,50640,552,7334
#
# --> return NULL...
#
# Processing cGEP4 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP5 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP6 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP7 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP8 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP9 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP10 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP11 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP12 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP13 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP14 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP15 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP16 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP17 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP18 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP19 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP20 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP21 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP22 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP23 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP24 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID: 3162,54407,5663,57555,10950,334
#
# --> return NULL...
#
# Processing cGEP25 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP26 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP27 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP28 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP29 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP30 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP31 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP32 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP33 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP34 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP35 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP36 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP37 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP38 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP39 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP40 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP41 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP42 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP43 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP44 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP45 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP46 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP47 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP48 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP49 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP50 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP51 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP52 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP53 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP54 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP55 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP56 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP57 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP58 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP59 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP60 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP61 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP62 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP63 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP64 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP65 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP66 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP67 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP68 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP69 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP70 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...

# %%
library(openxlsx)
library(dplyr)

wb <- createWorkbook()

# ===== 1. Hallmark =====
hallmark_df <- bind_rows(
  lapply(names(hallmark_list_results), function(cl){
    res <- hallmark_list_results[[cl]]@result
    if (is.null(res) || nrow(res)==0) return(NULL)
    res$Cluster <- cl
    res
  })
)

addWorksheet(wb, "Hallmark")
writeData(wb, "Hallmark", hallmark_df)

# ===== 2. Reactome =====
reactome_df <- bind_rows(
  lapply(names(reactome_list), function(cl){
    res <- reactome_list[[cl]]@result
    if (is.null(res) || nrow(res)==0) return(NULL)
    res$Cluster <- cl
    res
  })
)

addWorksheet(wb, "Reactome")
writeData(wb, "Reactome", reactome_df)

# ===== 3. GO BP =====
go_bp_df <- bind_rows(
  lapply(names(go_bp_list), function(cl){
    res <- go_bp_list[[cl]]@result
    if (is.null(res) || nrow(res)==0) return(NULL)
    res$Cluster <- cl
    res
  })
)

addWorksheet(wb, "GO_BP")
writeData(wb, "GO_BP", go_bp_df)

# ===== 保存 Excel 文件 =====
saveWorkbook(wb, "./3.2.CD8T_GEP_pathway/3.2.CD8T_Cluster_Pathway_Results.xlsx", overwrite = TRUE)

# %%
library(openxlsx)
library(dplyr)
library(readr)
library(stringr)

# ==============================================================================
# 1. 读取 Jaccard 注释结果
# ==============================================================================
JACCARD_FILE <- "/sibcb1/bioinformatics/yangyue/project/immunotherapy/7.2.cNMF_CD8T/3.cGEP_topgene/test/cGEP1_70_function_CD8_Spectra52_annotation_sort.csv"

if (file.exists(JACCARD_FILE)) {
  anno_df <- read_csv(JACCARD_FILE, show_col_types = FALSE)
  # 强制重命名第一列为 Cluster
  colnames(anno_df)[1] <- "Cluster"
  cat("✅ 成功读取 CSV。列名预览:", colnames(anno_df), "\n")
} else {
  stop("❌ 找不到文件！")
}

# ==============================================================================
# 2. 定义辅助函数 (已修复 select 冲突)
# ==============================================================================

# 函数1: 提取 Top 3 通路摘要
extract_top_summary <- function(enrich_list, db_prefix) {
  df_list <- lapply(names(enrich_list), function(cl) {
    res <- enrich_list[[cl]]@result
    
    if (is.null(res) || nrow(res) == 0) {
      return(data.frame(Cluster = cl, Pathways = "", stringsAsFactors = FALSE))
    }
    
    # 筛选显著并取前3
    top_res <- res %>% 
      filter(p.adjust < 0.05) %>% 
      arrange(p.adjust) %>% 
      head(3)
    
    path_str <- paste(top_res$Description, collapse = " | ")
    
    data.frame(Cluster = cl, Pathways = path_str, stringsAsFactors = FALSE)
  })
  
  combined_df <- bind_rows(df_list)
  
  # 重命名列 (使用 Base R 避免报错)
  target_col <- paste0("Top_", db_prefix)
  colnames(combined_df)[colnames(combined_df) == "Pathways"] <- target_col
  
  return(combined_df)
}

# 函数2: 提取详情 (【核心修复】：使用 dplyr::select)
extract_detail_df <- function(enrich_list) {
  bind_rows(lapply(names(enrich_list), function(cl) {
    res <- enrich_list[[cl]]@result
    if (is.null(res) || nrow(res) == 0) return(NULL)
    
    res$Cluster <- cl
    
    # 【这里修改了】：强制使用 dplyr::select，防止被 AnnotationDbi 覆盖
    res %>% dplyr::select(Cluster, everything())
  }))
}

# ==============================================================================
# 3. 执行提取与合并
# ==============================================================================
cat("正在提取 Hallmark...\n")
hallmark_sum <- extract_top_summary(hallmark_list_results, "Hallmark")
hallmark_det <- extract_detail_df(hallmark_list_results)

cat("正在提取 Reactome...\n")
reactome_sum <- extract_top_summary(reactome_list, "Reactome")
reactome_det <- extract_detail_df(reactome_list)

cat("正在提取 GO_BP...\n")
go_bp_sum    <- extract_top_summary(go_bp_list, "GO_BP")
go_bp_det    <- extract_detail_df(go_bp_list)

# 合并到总表
final_anno_df <- anno_df %>%
  left_join(hallmark_sum, by = "Cluster") %>%
  left_join(reactome_sum, by = "Cluster") %>%
  left_join(go_bp_sum,    by = "Cluster")

# ==============================================================================
# 4. 写入 Excel
# ==============================================================================
OUT_XLSX <- "./3.2.CD8T_GEP_pathway/3.CD8T_Cluster_Pathway_Master_Annotation.xlsx"
wb <- createWorkbook()

# Sheet 1: 总览
addWorksheet(wb, "Summary_Overview")
writeData(wb, "Summary_Overview", final_anno_df)
freezePane(wb, "Summary_Overview", firstRow = TRUE)

# Sheet 2: Hallmark 详情
addWorksheet(wb, "Detail_Hallmark")
writeData(wb, "Detail_Hallmark", hallmark_det)

# Sheet 3: Reactome 详情
addWorksheet(wb, "Detail_Reactome")
writeData(wb, "Detail_Reactome", reactome_det)

# Sheet 4: GO_BP 详情
addWorksheet(wb, "Detail_GO_BP")
writeData(wb, "Detail_GO_BP", go_bp_det)

saveWorkbook(wb, OUT_XLSX, overwrite = TRUE)

cat("--------------------------------------------------\n")
cat("✅ 成功！所有冲突已修复。\n")
cat("📄 文件已保存至:", OUT_XLSX, "\n")
cat("--------------------------------------------------\n")
# Out:
# Warning message:
# “程辑包‘readr’是用R版本4.2.3 来建造的”
# ✅ 成功读取 CSV。列名预览: Cluster Spectra_Label Overlap_Count Jaccard_Score Key_Markers Top_genes_in_cGEP
# 正在提取 Hallmark...
# 正在提取 Reactome...
# 正在提取 GO_BP...
# --------------------------------------------------
# ✅ 成功！所有冲突已修复。
# 📄 文件已保存至: ./3.2.CD8T_GEP_pathway/3.CD8T_Cluster_Pathway_Master_Annotation.xlsx
# --------------------------------------------------
