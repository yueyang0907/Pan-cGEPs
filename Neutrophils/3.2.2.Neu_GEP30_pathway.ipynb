# %%
library(dplyr)
library(tidyr)
library(pheatmap)
library(viridis)
library(tools)
library(cluster)
library(igraph)
library(tibble)

library(clusterProfiler)
library(org.Hs.eg.db)
library(dplyr)
# Out:
# Warning message:
# “程辑包‘dplyr’是用R版本4.2.3 来建造的”
#
# 载入程辑包：‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# “程辑包‘tidyr’是用R版本4.2.3 来建造的”
# Warning message:
# “程辑包‘viridis’是用R版本4.2.3 来建造的”
# 载入需要的程辑包：viridisLite
#
# Warning message:
# “程辑包‘viridisLite’是用R版本4.2.3 来建造的”
# Warning message:
# “程辑包‘cluster’是用R版本4.2.3 来建造的”
#
# 载入程辑包：‘igraph’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     crossing
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     as_data_frame, groups, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
#
# 载入程辑包：‘tibble’
#
#
# The following object is masked from ‘package:igraph’:
#
#     as_data_frame
#
#
# Warning message:
# “程辑包‘clusterProfiler’是用R版本4.2.2 来建造的”
#
#
# Registered S3 methods overwritten by 'treeio':
#   method              from
#   MRCA.phylo          tidytree
#   MRCA.treedata       tidytree
#   Nnode.treedata      tidytree
#   Ntip.treedata       tidytree
#   ancestor.phylo      tidytree
#   ancestor.treedata   tidytree
#   child.phylo         tidytree
#   child.treedata      tidytree
#   full_join.phylo     tidytree
#   full_join.treedata  tidytree
#   groupClade.phylo    tidytree
#   groupClade.treedata tidytree
#   groupOTU.phylo      tidytree
#   groupOTU.treedata   tidytree
#   is.rooted.treedata  tidytree
#   nodeid.phylo        tidytree
#   nodeid.treedata     tidytree
#   nodelab.phylo       tidytree
#   nodelab.treedata    tidytree
#   offspring.phylo     tidytree
#   offspring.treedata  tidytree
#   parent.phylo        tidytree
#   parent.treedata     tidytree
#   root.treedata       tidytree
#   rootnode.phylo      tidytree
#   sibling.phylo       tidytree
#
# clusterProfiler v4.6.0  For help: https://yulab-smu.top/biomedical-knowledge-mining-book/
#
# If you use clusterProfiler in published research, please cite:
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal enrichment tool for interpreting omics data. The Innovation. 2021, 2(3):100141
#
#
# 载入程辑包：‘clusterProfiler’
#
#
# The following object is masked from ‘package:igraph’:
#
#     simplify
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# 载入需要的程辑包：AnnotationDbi
#
# 载入需要的程辑包：stats4
#
# 载入需要的程辑包：BiocGenerics
#
#
# 载入程辑包：‘BiocGenerics’
#
#
# The following objects are masked from ‘package:igraph’:
#
#     normalize, path, union
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# 载入需要的程辑包：Biobase
#
# Warning message:
# “程辑包‘Biobase’是用R版本4.2.3 来建造的”
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# 载入需要的程辑包：IRanges
#
# Warning message:
# “程辑包‘IRanges’是用R版本4.2.3 来建造的”
# 载入需要的程辑包：S4Vectors
#
#
# 载入程辑包：‘S4Vectors’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
#
# 载入程辑包：‘IRanges’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
#
# 载入程辑包：‘AnnotationDbi’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select

# %%
# 读入
signature_Neu <- read.csv(
  "Example_refbuilder_Neutrophils/ALL_cGEP_top_genes_Neutrophils_wide.csv",
  check.names = FALSE,
  stringsAsFactors = FALSE
)

# 转成 list（核心）
cluster_genes <- lapply(signature_Neu, function(x) {
  x[!is.na(x) & x != ""]
})
cluster_genes
# Out:
# $cGEP1
#  [1] "CD3G"      "IL32"      "LCK"       "CCL5"      "CD3E"      "GZMA"
#  [7] "NKG7"      "CD2"       "TRBC2"     "ITM2A"     "CD3D"      "CD27"
# [13] "TRAC"      "IKZF3"     "GZMH"      "RASGRP1"   "TRAT1"     "CTLA4"
# [19] "ETS1"      "GZMK"      "CD8B"      "CD8A"      "SYNE2"     "TRBC1"
# [25] "CTSW"      "CST7"      "LINC00426" "CD7"       "PRF1"      "SKAP1"
#
# $cGEP2
#  [1] "CXCR5"     "LINC01641" "GAS5"      "RPS8"      "RPS18"     "RPS2"
#  [7] "RPL37A"    "RPLP2"     "RPL23A"    "RPS23"     "RPS12"     "RPL18A"
# [13] "RPL10A"    "RPL3"      "RPS27"     "RPS29"     "RPL13"     "RPL13A"
# [19] "EEF1A1"    "RPS6"      "RPL41"     "RPL10"     "TRBC1"     "RPS3"
# [25] "RPL4"      "RPS17"     "SNHG6"     "RPS20"     "RPS14"     "RPL19"
#
# $cGEP3
#  [1] "S100A9"   "S100A12"  "S100A8"   "VCAN"     "LYZ"      "PLBD1"
#  [7] "VIM"      "SERPINB1" "METTL9"   "HP"       "TKT"      "MNDA"
# [13] "PADI4"    "GCA"      "GAPDH"    "APLP2"    "SLC2A3"   "ITGAM"
# [19] "IRS2"     "IVNS1ABP" "CKAP4"    "HMGB2"    "MXD1"     "CES1"
# [25] "TSPO"     "GM2A"     "TALDO1"   "ANXA1"    "SELL"     "RBP7"
#
# $cGEP4
#  [1] "IER3"       "IL1B"       "NFKBIA"     "NLRP3"      "AC095055.1"
#  [6] "TNFAIP3"    "VEGFA"      "KDM6B"      "ZNF331"     "INSIG1"
# [11] "GPR183"     "MAP3K8"     "AC092368.3" "EREG"       "CXCL2"
# [16] "GRASP"      "CXCL8"      "AC016831.7" "RASGEF1B"   "PLAUR"
# [21] "NR4A1"      "THBS1"      "NAMPT"      "CD83"       "ARF4-AS1"
# [26] "CLHC1"      "HLA-DQB2"   "PIM3"       "MRPS24"     "CSRNP1"
#
# $cGEP5
#  [1] "IFIT1"      "RSAD2"      "IFIT3"      "ISG15"      "MX1"
#  [6] "HERC5"      "IFIT2"      "GBP1"       "CMPK2"      "SPDEF"
# [11] "AC010501.1" "OAS2"       "AC138907.8" "IFI44L"     "SERPING1"
# [16] "IFITM3"     "GBP5"       "GBP4"       "IFI6"       "AC007362.1"
# [21] "EPSTI1"     "RNF213"     "DDX58"      "AC148477.3" "UBE2L6"
# [26] "XAF1"       "STAT1"      "AC113189.2" "LINC02453"  "TNFSF13B"
#
# $cGEP6
#  [1] "FCGR3A"     "RYR3"       "AIF1"       "C1QA"       "LST1"
#  [6] "IFITM3"     "RHOC"       "SMIM25"     "CDKN1C"     "C1QB"
# [11] "FCER1G"     "CLIC2"      "CD79B"      "ABI3"       "CSF1R"
# [16] "AC007038.1" "TCF7L2"     "ATP8B1"     "FMNL2"      "CEBPB"
# [21] "TRNP1"      "LINC02449"  "DRAP1"      "AC124045.1" "COTL1"
# [26] "MTSS1"      "LRRC25"     "L1TD1"      "RPS19"      "C1QC"
#
# $cGEP7
#  [1] "HLA-DQA1"   "FCER1A"     "HLA-DRA"    "HLA-DPA1"   "HLA-DQA2"
#  [6] "RGS1"       "HLA-DPB1"   "HLA-DQB1"   "HLA-DRB1"   "HLA-DRB5"
# [11] "CLEC10A"    "CD74"       "HIST1H3A"   "HLA-DMA"    "CD1C"
# [16] "CCSER1"     "AC102953.2" "AL390728.5" "ZNF697"     "MRC1"
# [21] "ZNF790"     "HLA-DOA"    "TNFRSF21"   "LINC01970"  "AC124068.2"
# [26] "CST7"       "SH3BP4"     "ZNF597"     "TNFRSF12A"  "RGL1"
#
# $cGEP8
#  [1] "BCL2"       "AL049840.1" "LOH12CR2"   "AC092368.3" "RILPL1"
#  [6] "CCNH"       "CDKN2A"     "SNX24"      "AL117339.5" "YES1"
# [11] "ACVRL1"     "AL450326.1" "POLR3B"     "CDKL3"      "AL138820.1"
# [16] "TUBGCP5"    "AC119428.2" "AL590617.2" "ZNF517"     "NPM3"
# [21] "HOXB3"      "CAMK4"      "CNTNAP2"    "HYPK"       "AC124242.1"
# [26] "TFRC"       "IKZF4"      "AC114490.2" "TMEM236"    "AC005838.2"
#
# $cGEP9
#  [1] "PLK2"       "MSR1"       "C3"         "ACVRL1"     "ACKR3"
#  [6] "APOC1"      "ZNF707"     "SPARC"      "PHLDA1"     "AC011043.1"
# [11] "CD81"       "LTC4S"      "TBX6"       "ZBED3-AS1"  "AC005076.1"
# [16] "LINC01431"  "NRP1"       "OSM"        "AL357060.1" "SLC2A5"
# [21] "PSD"        "MARCO"      "WDR76"      "AL450326.1" "GPT2"
# [26] "OLR1"       "UBE3D"      "FN1"        "LINC01678"  "EPS8L1"
#
# $cGEP10
#  [1] "ZNF521"     "STMN2"      "RBFOX1"     "KCNIP4"     "CDCA5"
#  [6] "ZNF462"     "PKIA"       "BEX3"       "SYN1"       "MPP3"
# [11] "SYT4"       "NEUROD1"    "IGSF21"     "SH3PXD2A"   "RNF144A"
# [16] "TRPM3"      "BEX1"       "NCS1"       "PTHLH"      "NRN1"
# [21] "AL158835.1" "AC004540.2" "ST18"       "ZBTB18"     "SGIP1"
# [26] "DYNC1I1"    "CCND2"      "MAGI3"      "DTNA"       "NNAT"
#
# $cGEP11
#  [1] "MGP"       "SFRP1"     "FAM19A5"   "KIF21A"    "PDLIM3"    "LINC01315"
#  [7] "BAIAP2L2"  "KHDRBS3"   "NTRK3"     "SLIT1"     "EXOC3L1"   "KIF26A"
# [13] "BOC"       "ELAVL4"    "INSM1"     "RHOBTB3"   "FOXS1"     "CDH15"
# [19] "ANK3"      "RGMB"      "MIR99AHG"  "ZNF681"    "FAM57B"    "FAM161B"
# [25] "APBB2"     "SP5"       "ACVR2B"    "PAK3"      "ZIC2"      "PCNT"
#
# $cGEP12
#  [1] "CENPV"     "TMSB15A"   "CCDC34"    "MYBL2"     "CENPF"     "RAI14"
#  [7] "GJC1"      "FANCG"     "FAM84A"    "TMEM108"   "UBE2T"     "DHCR24"
# [13] "CPLX1"     "ABCA3"     "PAX6"      "MAP1B"     "PHF21B"    "BDH1"
# [19] "PHGDH"     "ZIC2"      "NAT8L"     "SPAG16"    "NSD2"      "E2F1"
# [25] "TMCC1-AS1" "GTSE1"     "FARP1"     "FRRS1L"    "DCHS1"     "SLC29A4"
#
# $cGEP13
#  [1] "CXCR2"      "B2M"        "TAGLN2"     "TXNIP"      "NEAT1"
#  [6] "TSC22D3"    "CPPED1"     "SEC14L1"    "MALAT1"     "NCOA4"
# [11] "SOD2"       "ITM2B"      "RNASET2"    "TNFAIP2"    "VMP1"
# [16] "HLA-B"      "P2RY13"     "SLC25A37"   "LYN"        "HLA-C"
# [21] "IFITM2"     "H3F3A"      "GNG10"      "ADGRE5"     "OAZ2"
# [26] "KCTD21-AS1" "PTPRC"      "FAM129A"    "LRRC25"     "LRRFIP1"
#
# $cGEP14
#  [1] "S100A9"  "S100A12" "MMP9"    "S100A8"  "RFLNB"   "PADI4"   "S100A6"
#  [8] "ACTB"    "HMGB2"   "ALOX5AP" "FCN1"    "TSPO"    "GAPDH"   "APMAP"
# [15] "CST7"    "S100A4"  "CDA"     "TXN"     "CKAP4"   "PGLYRP1" "GRN"
# [22] "NCF1"    "CTSD"    "CAP1"    "PGD"     "GNG2"    "VIM"     "PYGL"
# [29] "FOLR3"   "QPCT"
#
# $cGEP15
#  [1] "G0S2"       "PLAUR"      "SAMSN1"     "JOSD1"      "AC245128.3"
#  [6] "PFKFB3"     "CXCL8"      "OSM"        "PTGS2"      "TRIB1"
# [11] "SRGN"       "FTH1"       "NR4A3"      "SOCS3"      "IVNS1ABP"
# [16] "CSRNP1"     "IER3"       "SYAP1"      "CD55"       "SAT1"
# [21] "ACTG1"      "FRMD4B"     "PLEK"       "SLC2A3"     "BCL2A1"
# [26] "MCL1"       "ETS2"       "CREM"       "DDIT4"      "ELL2"
#
# $cGEP16
#  [1] "MT-ATP6"   "MT-CO1"    "MT-ND4"    "MT-CO3"    "MT-CYB"    "MT-ND1"
#  [7] "MT-ND3"    "MT-ATP8"   "MT-CO2"    "MT-ND5"    "MT-ND2"    "MT-ND4L"
# [13] "MIAT"      "VCAN"      "SPINK4"    "MUC5AC"    "MT-RNR2"   "PSCA"
# [19] "KRTAP4-8"  "CDC42BPG"  "PHF10"     "PLXNB2"    "ADO"       "MARCH1"
# [25] "SH3BP4"    "MT-RNR1"   "MALAT1"    "RNF217"    "TMEM190"   "LINC00315"
#
# $cGEP17
#  [1] "PF4"       "PPBP"      "NRGN"      "F13A1"     "CAVIN2"    "MPIG6B"
#  [7] "PRKAR2B"   "TUBB1"     "CTDSPL"    "SCFD2"     "GRAP2"     "TSC22D1"
# [13] "GP9"       "CLU"       "CMTM5"     "SPARC"     "ITGA2B"    "ITGB5"
# [19] "MYL9"      "PTCRA"     "SH3BGRL2"  "CLDN5"     "CDKN1A"    "CCL5"
# [25] "PDLIM1"    "HIST1H2AE" "GPX1"      "PF4V1"     "ALOX12"    "BEX3"
#
# $cGEP18
#  [1] "LCN2"      "RETN"      "LTF"       "CD24"      "CEACAM8"   "BPI"
#  [7] "CAMP"      "CEACAM6"   "CRISP3"    "LYZ"       "OLFM4"     "RNASE2"
# [13] "TCN1"      "RNASE3"    "STOM"      "MS4A3"     "CEBPE"     "HTRA3"
# [19] "COL17A1"   "DEFA4"     "TFF3"      "LINC02009" "ABCA13"    "CTSG"
# [25] "MMP8"      "ERG"       "AZU1"      "PRTN3"     "BEX1"      "C20orf27"
#
# $cGEP19
#  [1] "IGKC"        "IGHG2"       "IGHG1"       "HSPB1"       "IGHG3"
#  [6] "C10orf10"    "BAG3"        "HSPA1B"      "MTRR"        "JUN"
# [11] "IGHG4"       "XBP1"        "ARID5B"      "ROR2"        "EEF1E1"
# [16] "HSPA1A"      "SIL1"        "NUDT13"      "PLA2G16"     "DNAJB1"
# [21] "TPRN"        "GS1-124K5.4" "LINC00689"   "PPM1N"       "RHEBL1"
# [26] "LINC02487"   "GLO1"        "GPR39"       "BHLHE41"     "YIF1A"
#
# $cGEP20
#  [1] "TGFA"      "RASSF6"    "GLIS3"     "MET"       "LPIN3"     "CDH4"
#  [7] "CCND1"     "ATP1B1"    "LINC01320" "ANGPTL4"   "LINC02532" "PKHD1"
# [13] "BHLHE41"   "CLDN2"     "CP"        "TMEM67"    "CGNL1"     "UGT2A3"
# [19] "SLC3A1"    "MT-ND4"    "HSF4"      "MEST"      "OSGEPL1"   "LINC00665"
# [25] "SBF2-AS1"  "IRX3"      "CLDN3"     "PLEKHH2"   "MYEF2"     "CHPF"
#
# $cGEP21
#  [1] "CD9"         "SLC16A10"    "FN1"         "FPR3"        "CARMIL1"
#  [6] "VSIG4"       "SH3D19"      "HS3ST1"      "OLR1"        "TNFRSF4"
# [11] "CRACR2B"     "FAN1"        "ZGRF1"       "GSDME"       "PMEPA1"
# [16] "RAMP3"       "PARM1"       "C3"          "JAG1"        "CLEC5A"
# [21] "EIF5AL1"     "THBD"        "DOLK"        "SLC16A1-AS1" "POP1"
# [26] "CD81"        "P2RY6"       "LRIF1"       "AC009812.1"  "NLE1"
#
# $cGEP22
#  [1] "APOE"       "TREM2"      "C1QC"       "UNC5B"      "SCIN"
#  [6] "SDS"        "LIF"        "C1QB"       "APOC1"      "RASSF8"
# [11] "HTR7"       "NAV2"       "A2M"        "ZNF205"     "SLC38A1"
# [16] "CD74"       "ACOT11"     "SLC24A1"    "KCNMA1"     "AL391069.3"
# [21] "PPM1H"      "DKK3"       "NEXN"       "ABHD5"      "TSPYL2"
# [26] "SLC1A3"     "HLA-DPA1"   "HLTF"       "KIAA0355"   "HLA-DQB1"
#
# $cGEP23
#  [1] "RGS5"        "PDGFRB"      "MYO1B"       "WEE1"        "ZNF793"
#  [6] "TNS2"        "EBF1"        "BGN"         "IGFBP7"      "RBMS3"
# [11] "NR2F2"       "SNCG"        "SPARC"       "TSHZ2"       "TNS1"
# [16] "CALD1"       "MYLK"        "CASC15"      "COL4A2"      "KLF8"
# [21] "ITGA3"       "CAV1"        "PRUNE2"      "COL6A2"      "MGP"
# [26] "SLC16A1-AS1" "MOK"         "COL4A1"      "TPM1"        "MTUS1"
#
# $cGEP24
#  [1] "SPRY1"    "ESM1"     "TM4SF18"  "MEIS2"    "KDR"      "GJA1"
#  [7] "DOCK9"    "PBX1"     "IGFBP5"   "NOSTRIN"  "WWTR1"    "PDGFD"
# [13] "CA4"      "EPN2"     "PIK3R3"   "ARHGAP29" "AKAP12"   "COL8A1"
# [19] "RBP5"     "KANK3"    "PTPRB"    "EMCN"     "ZNF79"    "CAVIN2"
# [25] "ZNF704"   "AFAP1L1"  "SPARCL1"  "FCN3"     "VWF"      "CRIM1"
#
# $cGEP25
#  [1] "C1QB"     "C1QC"     "C1QA"     "TMEM176B" "MS4A6A"   "MS4A4A"
#  [7] "ITM2B"    "NPC2"     "FCGRT"    "IL2RA"    "FUCA1"    "PLTP"
# [13] "FOLR2"    "TSPAN4"   "CD74"     "HLA-C"    "CST3"     "CTSC"
# [19] "HLA-DMB"  "VSIG4"    "TMEM176A" "GPR34"    "HLA-DMA"  "APOE"
# [25] "MGST2"    "SLC40A1"  "GRN"      "ADAMDEC1" "CTSZ"     "DNASE2"
#
# $cGEP26
#  [1] "GPNMB"  "RNASE1" "FTL"    "CTSD"   "LIPA"   "NUPR1"  "SPP1"   "SCD"
#  [9] "APLP2"  "TREM2"  "TGFBI"  "CD68"   "TIMP2"  "CD109"  "SLC2A1" "ADAM8"
# [17] "CSTB"   "CTSB"   "DAB2"   "AHNAK"  "FCGR2A" "RNF145" "ECM1"   "VAT1"
# [25] "IQGAP2" "LGALS3" "LGMN"   "VIM"    "MSR1"   "OTOA"
#
# $cGEP27
#  [1] "HSPA1A"   "JUN"      "KLF2"     "DNAJA4"   "IER5"     "HSPD1"
#  [7] "HSPA8"    "BAG3"     "HSP90AA1" "DNAJB1"   "HSP90AB1" "RHOB"
# [13] "HSPH1"    "DNAJA1"   "KLF4"     "PPP1R15A" "CLK1"     "HSPE1"
# [19] "UBC"      "TRA2B"    "ZFAND2A"  "EIF4A3"   "HSPA6"    "CHORDC1"
# [25] "KLF6"     "GADD45B"  "JUND"     "DNAJB6"   "BTG2"     "HSPA1B"
#
# $cGEP28
#  [1] "CHI3L1"  "FBP1"    "GPC4"    "RGCC"    "FAIM2"   "USP2"    "CA2"
#  [8] "TM4SF19" "CSTB"    "VIM"     "LILRB4"  "MATK"    "HRK"     "MARCO"
# [15] "SLC28A3" "FN1"     "LPL"     "GOLGA7B" "CAMP"    "CP"      "EFNA5"
# [22] "FABP3"   "EVL"     "MREG"    "CYP27B1" "GAL"     "FAH"     "CYP19A1"
# [29] "LGALS2"  "ARL4D"
#
# $cGEP29
#  [1] "MKI67"    "UBE2C"    "CDK1"     "HMMR"     "BIRC5"    "NUSAP1"
#  [7] "GTSE1"    "CCNA2"    "AURKB"    "H2AFZ"    "TUBB"     "STMN1"
# [13] "TOP2A"    "TPX2"     "CCNB2"    "HIST1H4C" "CDC20"    "TUBA1B"
# [19] "CKS1B"    "CCNB1"    "CENPM"    "CENPF"    "PTTG1"    "CEP55"
# [25] "SMC2"     "ANLN"     "TK1"      "PLK1"     "CDKN3"    "RRM2"
#
# $cGEP30
#  [1] "COL6A3"     "COL6A2"     "PAPPA"      "COL1A1"     "COL6A1"
#  [6] "TRIML2"     "FAM171B"    "SYT7"       "SLC22A17"   "NTN4"
# [11] "SV2A"       "TPBG"       "COL3A1"     "SNAP25"     "AEBP1"
# [16] "ADAMTS6"    "COL5A3"     "COL18A1"    "THBS2"      "ZNF66"
# [21] "TET1"       "TFPI"       "AC020688.1" "SGIP1"      "C1R"
# [26] "PRRX1"      "ITGA10"     "ITGB3"      "PKP3"       "HIF3A"

# %%
convert_gene <- function(gene_symbol_vector){
  bitr(gene_symbol_vector, 
       fromType = "SYMBOL",
       toType = "ENTREZID",
       OrgDb = org.Hs.eg.db) %>%
    pull(ENTREZID)
}

clean_symbol <- function(x){
  x <- unique(x)
  x <- x[x != ""]
  x <- toupper(x)
  x
}

cluster_genes <- lapply(cluster_genes, clean_symbol)

# %%
library(clusterProfiler)
library(org.Hs.eg.db)
library(ReactomePA)
library(msigdbr)
library(dplyr)

# ============================
# 清洗基因名
# ============================
clean_symbol <- function(x){
  x <- unique(toupper(x))
  x[x != ""]
}

cluster_genes <- lapply(cluster_genes, clean_symbol)

# ============================
# SYMBOL → ENTREZ 映射
# ============================
all_symbols <- unique(unlist(cluster_genes))

symbol2entrez <- bitr(all_symbols,
                      fromType="SYMBOL",
                      toType="ENTREZID",
                      OrgDb=org.Hs.eg.db)

# named vector
map_table <- symbol2entrez$ENTREZID
names(map_table) <- symbol2entrez$SYMBOL

# ============================
# MSigDB Hallmark gene sets
# ============================
msig_h <- msigdbr(species = "Homo sapiens", category = "H")

hallmark_list <- msig_h %>% 
  split(.$entrez_gene) %>%
  lapply(function(x) x$gs_name)

# ============================
# 初始化结果表
# ============================
kegg_list <- list()
go_bp_list <- list()
reactome_list <- list()
hallmark_list_results <- list()

# ============================
# 循环 77 clusters
# ============================
for(cl in names(cluster_genes)){

  message("Processing ", cl, " ...")

  # SYMBOL → ENTREZ
  genes <- cluster_genes[[cl]]
  genes_entrez <- map_table[genes]
  genes_entrez <- genes_entrez[!is.na(genes_entrez)]

  if(length(genes_entrez) < 5){
    warning(cl, ": <5 valid genes → skip")
    next
  }

  # KEGG（可以为空）
  kegg_list[[cl]] <- tryCatch({
    enrichKEGG(gene = genes_entrez, organism = "hsa",
               pvalueCutoff = 0.1)
  }, error=function(e) NULL)

  # GO BP
  go_bp_list[[cl]] <- enrichGO(gene = genes_entrez, 
                               OrgDb = org.Hs.eg.db,
                               keyType="ENTREZID",
                               ont="BP",
                               pvalueCutoff=0.1)

  # Reactome（强烈推荐）
  reactome_list[[cl]] <- enrichPathway(gene = genes_entrez,
                                       pvalueCutoff = 0.1,
                                       readable = TRUE)

  # Hallmark enrichment
  hallmark_list_results[[cl]] <- enricher(
    gene = genes_entrez,
    TERM2GENE = msig_h[,c("gs_name","entrez_gene")],
    pvalueCutoff = 0.1
  )
}
# Out:
# ReactomePA v1.42.0  For help: https://yulab-smu.top/biomedical-knowledge-mining-book/
#
# If you use ReactomePA in published research, please cite:
# Guangchuang Yu, Qing-Yu He. ReactomePA: an R/Bioconductor package for reactome pathway analysis and visualization. Molecular BioSystems 2016, 12(2):477-479
#
# 'select()' returned 1:1 mapping between keys and columns
#
# Warning message in bitr(all_symbols, fromType = "SYMBOL", toType = "ENTREZID", OrgDb = org.Hs.eg.db):
# “7.8% of input gene IDs are fail to map...”
# Processing cGEP1 ...
#
# Reading KEGG annotation online: "https://rest.kegg.jp/link/hsa/pathway"...
#
# Reading KEGG annotation online: "https://rest.kegg.jp/list/pathway"...
#
# Warning message in utils::download.file(url, quiet = TRUE, method = method, ...):
# “URL 'https://rest.kegg.jp/list/pathway': Timeout of 300 seconds was reached”
# fail to download KEGG data...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP2 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP3 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP4 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP5 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP6 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP7 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP8 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP9 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP10 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP11 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP12 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP13 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP14 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP15 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP16 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP17 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP18 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP19 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP20 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP21 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP22 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP23 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP24 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP25 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP26 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP27 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP28 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP29 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...
#
# Processing cGEP30 ...
#
# --> No gene can be mapped....
#
# --> Expected input gene ID:
#
# --> return NULL...

# %%
hallmark_list_results
# Out:
# $cGEP1
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:30] "917" "9235" "3932" "6352" "916" "3001" "4818" "914" "28638" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...2 enriched terms found
# 'data.frame':	2 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_ALLOGRAFT_REJECTION" "HALLMARK_COMPLEMENT"
#  $ Description: chr  "HALLMARK_ALLOGRAFT_REJECTION" "HALLMARK_COMPLEMENT"
#  $ GeneRatio  : chr  "13/18" "5/18"
#  $ BgRatio    : chr  "200/4383" "200/4383"
#  $ pvalue     : num  1.78e-14 9.91e-04
#  $ p.adjust   : num  2.49e-13 6.94e-03
#  $ qvalue     : num  2.06e-13 5.74e-03
#  $ geneID     : chr  "917/3932/6352/916/3001/914/915/50852/2113/926/925/924/5551" "3932/6352/3001/10125/3003"
#  $ Count      : int  13 5
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP2
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:30] "643" "107985463" "60674" "6202" "6222" "6187" "6168" "6181" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...1 enriched terms found
# 'data.frame':	1 obs. of  9 variables:
#  $ ID         : chr "HALLMARK_MYC_TARGETS_V1"
#  $ Description: chr "HALLMARK_MYC_TARGETS_V1"
#  $ GeneRatio  : chr "3/5"
#  $ BgRatio    : chr "200/4383"
#  $ pvalue     : num 0.000874
#  $ p.adjust   : num 0.00262
#  $ qvalue     : num 0.00184
#  $ geneID     : chr "6187/6194/6188"
#  $ Count      : int 3
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP3
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:30] "6280" "6283" "6279" "1462" "4069" "79887" "7431" "1992" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...0 enriched terms found
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP4
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:26] "8870" "3553" "4792" "114548" "7128" "7422" "23135" "55422" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...5 enriched terms found
# 'data.frame':	5 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_TNFA_SIGNALING_VIA_NFKB" "HALLMARK_INFLAMMATORY_RESPONSE" "HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION" "HALLMARK_HYPOXIA" ...
#  $ Description: chr  "HALLMARK_TNFA_SIGNALING_VIA_NFKB" "HALLMARK_INFLAMMATORY_RESPONSE" "HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION" "HALLMARK_HYPOXIA" ...
#  $ GeneRatio  : chr  "13/19" "8/19" "5/19" "4/19" ...
#  $ BgRatio    : chr  "200/4383" "200/4383" "200/4383" "200/4383" ...
#  $ pvalue     : num  5.41e-14 8.01e-07 1.30e-03 9.50e-03 9.50e-03
#  $ p.adjust   : num  1.41e-12 1.04e-05 1.12e-02 4.94e-02 4.94e-02
#  $ qvalue     : num  1.08e-12 8.01e-06 8.64e-03 3.80e-02 3.80e-02
#  $ geneID     : chr  "8870/3553/4792/7128/7422/23135/1880/1326/2920/5329/3164/10135/9308" "3553/4792/114548/1880/2069/3576/5329/10135" "7128/7422/3576/5329/7057" "8870/7128/7422/5329" ...
#  $ Count      : int  13 8 5 4 4
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP5
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:24] "3434" "91543" "3437" "9636" "4599" "51191" "3433" "2633" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...2 enriched terms found
# 'data.frame':	2 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_INTERFERON_GAMMA_RESPONSE" "HALLMARK_INTERFERON_ALPHA_RESPONSE"
#  $ Description: chr  "HALLMARK_INTERFERON_GAMMA_RESPONSE" "HALLMARK_INTERFERON_ALPHA_RESPONSE"
#  $ GeneRatio  : chr  "17/18" "11/18"
#  $ BgRatio    : chr  "200/4383" "97/4383"
#  $ pvalue     : num  1.43e-22 9.82e-15
#  $ p.adjust   : num  2.14e-21 7.37e-14
#  $ qvalue     : num  1.8e-21 6.2e-14
#  $ geneID     : chr  "3434/91543/3437/9636/4599/3433/129607/4939/10964/710/10410/115361/94240/57674/9246/54739/6772" "91543/3437/9636/4599/3433/129607/10964/10410/115361/94240/9246"
#  $ Count      : int  17 11
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP6
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:27] "2214" "6263" "199" "712" "7940" "10410" "389" "1028" "713" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...2 enriched terms found
# 'data.frame':	2 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_COMPLEMENT" "HALLMARK_IL2_STAT5_SIGNALING"
#  $ Description: chr  "HALLMARK_COMPLEMENT" "HALLMARK_IL2_STAT5_SIGNALING"
#  $ GeneRatio  : chr  "4/11" "3/11"
#  $ BgRatio    : chr  "200/4383" "199/4383"
#  $ pvalue     : num  0.00108 0.01161
#  $ p.adjust   : num  0.0172 0.0929
#  $ qvalue     : num  0.0159 0.0855
#  $ geneID     : chr  "712/2207/1051/714" "10410/1028/974"
#  $ Count      : int  4 3
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP7
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:26] "3117" "2205" "3122" "3113" "3118" "5996" "3115" "3119" "3123" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...3 enriched terms found
# 'data.frame':	3 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_ALLOGRAFT_REJECTION" "HALLMARK_INTERFERON_GAMMA_RESPONSE" "HALLMARK_IL6_JAK_STAT3_SIGNALING"
#  $ Description: chr  "HALLMARK_ALLOGRAFT_REJECTION" "HALLMARK_INTERFERON_GAMMA_RESPONSE" "HALLMARK_IL6_JAK_STAT3_SIGNALING"
#  $ GeneRatio  : chr  "5/10" "4/10" "2/10"
#  $ BgRatio    : chr  "200/4383" "200/4383" "87/4383"
#  $ pvalue     : num  3.93e-05 7.11e-04 1.58e-02
#  $ p.adjust   : num  0.000393 0.003557 0.052683
#  $ qvalue     : num  0.00029 0.00262 0.03882
#  $ geneID     : chr  "3117/3122/972/3108/3111" "3117/3123/972/3108" "27242/51330"
#  $ Count      : int  5 4 2
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP8
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:20] "596" "503693" "353116" "902" "1029" "28966" "7525" "94" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...0 enriched terms found
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP9
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:26] "10769" "4481" "718" "94" "57007" "341" "286075" "6678" "22822" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...5 enriched terms found
# 'data.frame':	5 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_COAGULATION" "HALLMARK_COMPLEMENT" "HALLMARK_INFLAMMATORY_RESPONSE" "HALLMARK_TNFA_SIGNALING_VIA_NFKB" ...
#  $ Description: chr  "HALLMARK_COAGULATION" "HALLMARK_COMPLEMENT" "HALLMARK_INFLAMMATORY_RESPONSE" "HALLMARK_TNFA_SIGNALING_VIA_NFKB" ...
#  $ GeneRatio  : chr  "5/17" "4/17" "4/17" "4/17" ...
#  $ BgRatio    : chr  "138/4383" "200/4383" "200/4383" "200/4383" ...
#  $ pvalue     : num  0.000131 0.006266 0.006266 0.006266 0.008256
#  $ p.adjust   : num  0.00249 0.02976 0.02976 0.02976 0.03137
#  $ qvalue     : num  0.0018 0.0214 0.0214 0.0214 0.0226
#  $ geneID     : chr  "718/341/6678/4973/2335" "718/341/4973/2335" "4481/5008/8685/4973" "10769/57007/22822/4973" ...
#  $ Count      : int  5 4 4 4 2
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP10
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:28] "25925" "11075" "54715" "80333" "113130" "58499" "5569" "27018" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...0 enriched terms found
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP11
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:28] "4256" "6422" "55605" "27295" "102723775" "80115" "10656" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...1 enriched terms found
# 'data.frame':	1 obs. of  9 variables:
#  $ ID         : chr "HALLMARK_PANCREAS_BETA_CELLS"
#  $ Description: chr "HALLMARK_PANCREAS_BETA_CELLS"
#  $ GeneRatio  : chr "2/11"
#  $ BgRatio    : chr "40/4383"
#  $ pvalue     : num 0.00424
#  $ p.adjust   : num 0.0382
#  $ qvalue     : num 0.0357
#  $ geneID     : chr "3642/5063"
#  $ Count      : int 2
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP12
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:28] "201161" "11013" "91057" "4605" "1063" "26064" "10052" "2189" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...1 enriched terms found
# 'data.frame':	1 obs. of  9 variables:
#  $ ID         : chr "HALLMARK_G2M_CHECKPOINT"
#  $ Description: chr "HALLMARK_G2M_CHECKPOINT"
#  $ GeneRatio  : chr "4/11"
#  $ BgRatio    : chr "200/4383"
#  $ pvalue     : num 0.00108
#  $ p.adjust   : num 0.014
#  $ qvalue     : num 0.0125
#  $ geneID     : chr "4605/1063/7468/1869"
#  $ Count      : int 4
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP13
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:28] "3579" "567" "8407" "10628" "283131" "1831" "55313" "6397" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...5 enriched terms found
# 'data.frame':	5 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_INTERFERON_GAMMA_RESPONSE" "HALLMARK_INTERFERON_ALPHA_RESPONSE" "HALLMARK_ALLOGRAFT_REJECTION" "HALLMARK_HEME_METABOLISM" ...
#  $ Description: chr  "HALLMARK_INTERFERON_GAMMA_RESPONSE" "HALLMARK_INTERFERON_ALPHA_RESPONSE" "HALLMARK_ALLOGRAFT_REJECTION" "HALLMARK_HEME_METABOLISM" ...
#  $ GeneRatio  : chr  "6/12" "4/12" "3/12" "3/12" ...
#  $ BgRatio    : chr  "200/4383" "97/4383" "200/4383" "200/4383" ...
#  $ pvalue     : num  6.15e-06 9.74e-05 1.52e-02 1.52e-02 2.93e-02
#  $ p.adjust   : num  9.23e-05 7.31e-04 5.69e-02 5.69e-02 8.79e-02
#  $ qvalue     : num  6.48e-05 5.13e-04 3.99e-02 3.99e-02 6.17e-02
#  $ geneID     : chr  "567/10628/6648/7127/3106/10581" "567/10628/3107/10581" "567/4067/5788" "6397/8031/51312" ...
#  $ Count      : int  6 4 3 3 2
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP14
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:30] "6280" "6283" "4318" "6279" "359845" "23569" "6277" "60" "3148" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...1 enriched terms found
# 'data.frame':	1 obs. of  9 variables:
#  $ ID         : chr "HALLMARK_COMPLEMENT"
#  $ Description: chr "HALLMARK_COMPLEMENT"
#  $ GeneRatio  : chr "6/20"
#  $ BgRatio    : chr "200/4383"
#  $ pvalue     : num 0.00019
#  $ p.adjust   : num 0.0036
#  $ qvalue     : num 0.00339
#  $ geneID     : chr "6280/6283/2219/978/1509/54331"
#  $ Count      : int 6
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP15
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:29] "50486" "5329" "64092" "9929" "5209" "3576" "5008" "5743" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...4 enriched terms found
# 'data.frame':	4 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_TNFA_SIGNALING_VIA_NFKB" "HALLMARK_HYPOXIA" "HALLMARK_INFLAMMATORY_RESPONSE" "HALLMARK_KRAS_SIGNALING_UP"
#  $ Description: chr  "HALLMARK_TNFA_SIGNALING_VIA_NFKB" "HALLMARK_HYPOXIA" "HALLMARK_INFLAMMATORY_RESPONSE" "HALLMARK_KRAS_SIGNALING_UP"
#  $ GeneRatio  : chr  "14/21" "5/21" "4/21" "4/21"
#  $ BgRatio    : chr  "200/4383" "200/4383" "200/4383" "200/4383"
#  $ pvalue     : num  9.52e-15 2.10e-03 1.37e-02 1.37e-02
#  $ p.adjust   : num  2.38e-13 2.63e-02 8.54e-02 8.54e-02
#  $ qvalue     : num  1.90e-13 2.10e-02 6.83e-02 6.83e-02
#  $ geneID     : chr  "50486/5329/5209/5743/10221/8013/9021/8870/6303/5341/6515/597/4170/2114" "5329/5209/8870/6515/54541" "5329/3576/5008/1604" "50486/5329/5743/10221"
#  $ Count      : int  14 5 4 4
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP16
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:15] "440823" "1462" "27290" "4586" "8000" "728224" "55561" "55274" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...6 enriched terms found
# 'data.frame':	6 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_ANGIOGENESIS" "HALLMARK_APICAL_JUNCTION" "HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION" "HALLMARK_GLYCOLYSIS" ...
#  $ Description: chr  "HALLMARK_ANGIOGENESIS" "HALLMARK_APICAL_JUNCTION" "HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION" "HALLMARK_GLYCOLYSIS" ...
#  $ GeneRatio  : chr  "1/2" "1/2" "1/2" "1/2" ...
#  $ BgRatio    : chr  "36/4383" "200/4383" "200/4383" "200/4383" ...
#  $ pvalue     : num  0.0164 0.0892 0.0892 0.0892 0.0892 ...
#  $ p.adjust   : num  0.0892 0.0892 0.0892 0.0892 0.0892 ...
#  $ qvalue     : num  0.0782 0.0782 0.0782 0.0782 0.0782 ...
#  $ geneID     : chr  "1462" "1462" "1462" "1462" ...
#  $ Count      : int  1 1 1 1 1 1
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP17
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:29] "5196" "5473" "4900" "2162" "8436" "80739" "5577" "81027" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...2 enriched terms found
# 'data.frame':	2 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_COAGULATION" "HALLMARK_MYOGENESIS"
#  $ Description: chr  "HALLMARK_COAGULATION" "HALLMARK_MYOGENESIS"
#  $ GeneRatio  : chr  "4/17" "4/17"
#  $ BgRatio    : chr  "138/4383" "200/4383"
#  $ pvalue     : num  0.00163 0.00627
#  $ p.adjust   : num  0.0407 0.0783
#  $ qvalue     : num  0.0325 0.0627
#  $ geneID     : chr  "5196/2815/1191/6678" "1191/6678/3693/1026"
#  $ Count      : int  4 4
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP18
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:29] "3934" "56729" "4057" "100133941" "1088" "671" "820" "4680" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...3 enriched terms found
# 'data.frame':	3 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_ADIPOGENESIS" "HALLMARK_COMPLEMENT" "HALLMARK_ESTROGEN_RESPONSE_LATE"
#  $ Description: chr  "HALLMARK_ADIPOGENESIS" "HALLMARK_COMPLEMENT" "HALLMARK_ESTROGEN_RESPONSE_LATE"
#  $ GeneRatio  : chr  "2/6" "2/6" "2/6"
#  $ BgRatio    : chr  "200/4383" "200/4383" "200/4383"
#  $ pvalue     : num  0.0275 0.0275 0.0275
#  $ p.adjust   : num  0.0826 0.0826 0.0826
#  $ qvalue     : num  0.0579 0.0579 0.0579
#  $ geneID     : chr  "56729/2040" "4057/4317" "4057/7033"
#  $ Count      : int  2 2 2
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP19
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:27] "3514" "3501" "3500" "3315" "3502" "9531" "3304" "4552" "3725" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...1 enriched terms found
# 'data.frame':	1 obs. of  9 variables:
#  $ ID         : chr "HALLMARK_UNFOLDED_PROTEIN_RESPONSE"
#  $ Description: chr "HALLMARK_UNFOLDED_PROTEIN_RESPONSE"
#  $ GeneRatio  : chr "3/11"
#  $ BgRatio    : chr "113/4383"
#  $ pvalue     : num 0.00237
#  $ p.adjust   : num 0.0426
#  $ qvalue     : num 0.0424
#  $ geneID     : chr "9531/7494/10897"
#  $ Count      : int 3
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP20
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:29] "7039" "166824" "169792" "4233" "64900" "1002" "595" "481" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...1 enriched terms found
# 'data.frame':	1 obs. of  9 variables:
#  $ ID         : chr "HALLMARK_GLYCOLYSIS"
#  $ Description: chr "HALLMARK_GLYCOLYSIS"
#  $ GeneRatio  : chr "5/11"
#  $ BgRatio    : chr "200/4383"
#  $ pvalue     : num 6.95e-05
#  $ p.adjust   : num 0.00132
#  $ qvalue     : num 0.00132
#  $ geneID     : chr "7039/4233/51129/1365/79586"
#  $ Count      : int 5
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP21
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:29] "928" "117247" "2335" "2359" "55604" "11326" "152503" "9957" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...5 enriched terms found
# 'data.frame':	5 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_COAGULATION" "HALLMARK_ANGIOGENESIS" "HALLMARK_COMPLEMENT" "HALLMARK_TNFA_SIGNALING_VIA_NFKB" ...
#  $ Description: chr  "HALLMARK_COAGULATION" "HALLMARK_ANGIOGENESIS" "HALLMARK_COMPLEMENT" "HALLMARK_TNFA_SIGNALING_VIA_NFKB" ...
#  $ GeneRatio  : chr  "5/12" "3/12" "3/12" "3/12" ...
#  $ BgRatio    : chr  "138/4383" "36/4383" "200/4383" "200/4383" ...
#  $ pvalue     : num  1.91e-05 1.06e-04 1.52e-02 1.52e-02 1.66e-02
#  $ p.adjust   : num  0.000382 0.001064 0.066548 0.066548 0.066548
#  $ qvalue     : num  0.000301 0.00084 0.052538 0.052538 0.052538
#  $ geneID     : chr  "928/2335/4973/718/7056" "4973/182/7056" "2335/4973/718" "4973/56937/182" ...
#  $ Count      : int  5 3 3 3 2
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP22
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:28] "348" "54209" "714" "219699" "85477" "10993" "3976" "713" "341" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...0 enriched terms found
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP23
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:30] "8490" "5159" "4430" "7465" "390927" "23371" "1879" "633" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...3 enriched terms found
# 'data.frame':	3 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION" "HALLMARK_MYOGENESIS" "HALLMARK_APOPTOSIS"
#  $ Description: chr  "HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION" "HALLMARK_MYOGENESIS" "HALLMARK_APOPTOSIS"
#  $ GeneRatio  : chr  "10/16" "5/16" "4/16"
#  $ BgRatio    : chr  "200/4383" "200/4383" "161/4383"
#  $ pvalue     : num  1.98e-10 5.44e-04 2.26e-03
#  $ p.adjust   : num  2.37e-09 3.27e-03 9.03e-03
#  $ qvalue     : num  1.67e-09 2.29e-03 6.34e-03
#  $ geneID     : chr  "5159/633/6678/800/4638/1284/1292/4256/1282/7168" "3490/6678/4638/1284/1292" "5159/7465/633/857"
#  $ Count      : int  10 5 4
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP24
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:30] "10252" "11082" "116441" "4212" "3791" "2697" "23348" "5087" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...0 enriched terms found
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP25
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:30] "713" "714" "712" "28959" "64231" "51338" "9445" "10577" "2217" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...2 enriched terms found
# 'data.frame':	2 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_ALLOGRAFT_REJECTION" "HALLMARK_KRAS_SIGNALING_UP"
#  $ Description: chr  "HALLMARK_ALLOGRAFT_REJECTION" "HALLMARK_KRAS_SIGNALING_UP"
#  $ GeneRatio  : chr  "4/15" "4/15"
#  $ BgRatio    : chr  "200/4383" "200/4383"
#  $ pvalue     : num  0.00386 0.00386
#  $ p.adjust   : num  0.029 0.029
#  $ qvalue     : num  0.0224 0.0224
#  $ geneID     : chr  "3559/972/3109/3108" "28959/2517/55365/27299"
#  $ Count      : int  4 4
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP26
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:30] "10457" "6035" "2512" "1509" "3988" "26471" "6696" "6319" "334" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...4 enriched terms found
# 'data.frame':	4 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_COMPLEMENT" "HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION" "HALLMARK_CHOLESTEROL_HOMEOSTASIS" "HALLMARK_MTORC1_SIGNALING"
#  $ Description: chr  "HALLMARK_COMPLEMENT" "HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION" "HALLMARK_CHOLESTEROL_HOMEOSTASIS" "HALLMARK_MTORC1_SIGNALING"
#  $ GeneRatio  : chr  "6/21" "5/21" "3/21" "4/21"
#  $ BgRatio    : chr  "200/4383" "200/4383" "74/4383" "200/4383"
#  $ pvalue     : num  0.000256 0.002104 0.004939 0.013662
#  $ p.adjust   : num  0.00562 0.02314 0.03622 0.07514
#  $ qvalue     : num  0.00484 0.01993 0.03119 0.06471
#  $ geneID     : chr  "1509/3988/7077/1508/3958/5641" "6696/7045/1601/1893/7431" "6319/3958/5641" "26471/6319/6513/5641"
#  $ Count      : int  6 5 3 4
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP27
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:30] "3303" "3725" "10365" "55466" "51278" "3329" "3312" "9531" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...7 enriched terms found
# 'data.frame':	7 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_TNFA_SIGNALING_VIA_NFKB" "HALLMARK_APOPTOSIS" "HALLMARK_P53_PATHWAY" "HALLMARK_UV_RESPONSE_UP" ...
#  $ Description: chr  "HALLMARK_TNFA_SIGNALING_VIA_NFKB" "HALLMARK_APOPTOSIS" "HALLMARK_P53_PATHWAY" "HALLMARK_UV_RESPONSE_UP" ...
#  $ GeneRatio  : chr  "9/23" "5/23" "5/23" "4/23" ...
#  $ BgRatio    : chr  "200/4383" "161/4383" "200/4383" "158/4383" ...
#  $ pvalue     : num  3.36e-07 1.24e-03 3.23e-03 8.42e-03 1.88e-02 ...
#  $ p.adjust   : num  8.40e-06 1.54e-02 2.69e-02 5.27e-02 7.25e-02 ...
#  $ qvalue     : num  6.01e-06 1.11e-02 1.93e-02 3.77e-02 5.19e-02 ...
#  $ geneID     : chr  "3725/10365/51278/388/9314/23645/1316/4616/7832" "3725/388/3301/4616/7832" "3725/51278/9314/23645/7832" "3337/388/3301/7832" ...
#  $ Count      : int  9 5 5 4 4 4 3
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP28
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:30] "1116" "2203" "2239" "28984" "23017" "9099" "760" "116211" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...0 enriched terms found
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP29
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:28] "4288" "11065" "983" "3161" "332" "51203" "51512" "890" "9212" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...3 enriched terms found
# 'data.frame':	3 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_G2M_CHECKPOINT" "HALLMARK_E2F_TARGETS" "HALLMARK_MITOTIC_SPINDLE"
#  $ Description: chr  "HALLMARK_G2M_CHECKPOINT" "HALLMARK_E2F_TARGETS" "HALLMARK_MITOTIC_SPINDLE"
#  $ GeneRatio  : chr  "19/24" "17/24" "9/24"
#  $ BgRatio    : chr  "200/4383" "200/4383" "199/4383"
#  $ pvalue     : num  5.02e-22 2.16e-18 4.95e-07
#  $ p.adjust   : num  6.53e-21 1.40e-17 2.15e-06
#  $ qvalue     : num  4.76e-21 1.02e-17 1.56e-06
#  $ geneID     : chr  "4288/11065/983/3161/332/51203/890/9212/3925/7153/22974/9133/991/1163/1063/9232/10592/5347/1033" "4288/983/3161/332/9212/203068/3925/7153/9133/991/1163/79019/9232/7083/5347/1033/6241" "983/332/51203/7153/22974/9133/1063/54443/5347"
#  $ Count      : int  19 17 9
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141
#
#
# $cGEP30
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:29] "1293" "1292" "5069" "1277" "1291" "205860" "165215" "9066" ...
# #...pvalues adjusted by 'BH' with cutoff <0.1
# #...3 enriched terms found
# 'data.frame':	3 obs. of  9 variables:
#  $ ID         : chr  "HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION" "HALLMARK_MYOGENESIS" "HALLMARK_UV_RESPONSE_DN"
#  $ Description: chr  "HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION" "HALLMARK_MYOGENESIS" "HALLMARK_UV_RESPONSE_DN"
#  $ GeneRatio  : chr  "8/16" "5/16" "4/16"
#  $ BgRatio    : chr  "200/4383" "200/4383" "144/4383"
#  $ pvalue     : num  1.54e-07 5.44e-04 1.49e-03
#  $ p.adjust   : num  2.46e-06 4.35e-03 7.97e-03
#  $ qvalue     : num  1.94e-06 3.44e-03 6.29e-03
#  $ geneID     : chr  "1293/1292/1277/1281/50509/7058/5396/3690" "1293/1292/1277/1281/165" "1277/1281/7035/3690"
#  $ Count      : int  8 5 4
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141

# %%
library(openxlsx)
library(dplyr)

wb <- createWorkbook()

# ===== 1. Hallmark =====
hallmark_df <- bind_rows(
  lapply(names(hallmark_list_results), function(cl){
    res <- hallmark_list_results[[cl]]@result
    if (is.null(res) || nrow(res)==0) return(NULL)
    res$Cluster <- cl
    res
  })
)

addWorksheet(wb, "Hallmark")
writeData(wb, "Hallmark", hallmark_df)

# ===== 2. Reactome =====
reactome_df <- bind_rows(
  lapply(names(reactome_list), function(cl){
    res <- reactome_list[[cl]]@result
    if (is.null(res) || nrow(res)==0) return(NULL)
    res$Cluster <- cl
    res
  })
)

addWorksheet(wb, "Reactome")
writeData(wb, "Reactome", reactome_df)

# ===== 3. GO BP =====
go_bp_df <- bind_rows(
  lapply(names(go_bp_list), function(cl){
    res <- go_bp_list[[cl]]@result
    if (is.null(res) || nrow(res)==0) return(NULL)
    res$Cluster <- cl
    res
  })
)

addWorksheet(wb, "GO_BP")
writeData(wb, "GO_BP", go_bp_df)

# ===== 保存 Excel 文件 =====
saveWorkbook(wb, "./3.2.Neu_pathway/3.2.2.Neu_GEP30_Cluster_Pathway_Results.xlsx", overwrite = TRUE)

# %%
library(openxlsx)
library(dplyr)
library(readr)
library(stringr)

# ==============================================================================
# 1. 读取 Jaccard 注释结果
# ==============================================================================
JACCARD_FILE <- "/sibcb1/bioinformatics/yangyue/project/immunotherapy/7.5.cNMF_Neutrophils/3.Neutrophils_GEP_Anno/3.Neutrophil_cGEP30_Annotation_Results.csv"

if (file.exists(JACCARD_FILE)) {
  anno_df <- read_csv(JACCARD_FILE, show_col_types = FALSE)
  # 强制重命名第一列为 Cluster
  colnames(anno_df)[1] <- "Cluster"
  cat("✅ 成功读取 CSV。列名预览:", colnames(anno_df), "\n")
} else {
  stop("❌ 找不到文件！")
}

# ==============================================================================
# 2. 定义辅助函数 (已修复 select 冲突)
# ==============================================================================

# 函数1: 提取 Top 3 通路摘要
extract_top_summary <- function(enrich_list, db_prefix) {
  df_list <- lapply(names(enrich_list), function(cl) {
    res <- enrich_list[[cl]]@result
    
    if (is.null(res) || nrow(res) == 0) {
      return(data.frame(Cluster = cl, Pathways = "", stringsAsFactors = FALSE))
    }
    
    # 筛选显著并取前3
    top_res <- res %>% 
      filter(p.adjust < 0.05) %>% 
      arrange(p.adjust) %>% 
      head(3)
    
    path_str <- paste(top_res$Description, collapse = " | ")
    
    data.frame(Cluster = cl, Pathways = path_str, stringsAsFactors = FALSE)
  })
  
  combined_df <- bind_rows(df_list)
  
  # 重命名列 (使用 Base R 避免报错)
  target_col <- paste0("Top_", db_prefix)
  colnames(combined_df)[colnames(combined_df) == "Pathways"] <- target_col
  
  return(combined_df)
}

# 函数2: 提取详情 (【核心修复】：使用 dplyr::select)
extract_detail_df <- function(enrich_list) {
  bind_rows(lapply(names(enrich_list), function(cl) {
    res <- enrich_list[[cl]]@result
    if (is.null(res) || nrow(res) == 0) return(NULL)
    
    res$Cluster <- cl
    
    # 【这里修改了】：强制使用 dplyr::select，防止被 AnnotationDbi 覆盖
    res %>% dplyr::select(Cluster, everything())
  }))
}

# ==============================================================================
# 3. 执行提取与合并
# ==============================================================================
cat("正在提取 Hallmark...\n")
hallmark_sum <- extract_top_summary(hallmark_list_results, "Hallmark")
hallmark_det <- extract_detail_df(hallmark_list_results)

cat("正在提取 Reactome...\n")
reactome_sum <- extract_top_summary(reactome_list, "Reactome")
reactome_det <- extract_detail_df(reactome_list)

cat("正在提取 GO_BP...\n")
go_bp_sum    <- extract_top_summary(go_bp_list, "GO_BP")
go_bp_det    <- extract_detail_df(go_bp_list)

# 合并到总表
final_anno_df <- anno_df %>%
  left_join(hallmark_sum, by = "Cluster") %>%
  left_join(reactome_sum, by = "Cluster") %>%
  left_join(go_bp_sum,    by = "Cluster")

# ==============================================================================
# 4. 写入 Excel
# ==============================================================================
OUT_XLSX <- "./3.2.Neu_pathway/3.2.2.Neutrophils_GEP30_Cluster_Pathway_Master_Annotation.xlsx"
wb <- createWorkbook()

# Sheet 1: 总览
addWorksheet(wb, "Summary_Overview")
writeData(wb, "Summary_Overview", final_anno_df)
freezePane(wb, "Summary_Overview", firstRow = TRUE)

# Sheet 2: Hallmark 详情
addWorksheet(wb, "Detail_Hallmark")
writeData(wb, "Detail_Hallmark", hallmark_det)

# Sheet 3: Reactome 详情
addWorksheet(wb, "Detail_Reactome")
writeData(wb, "Detail_Reactome", reactome_det)

# Sheet 4: GO_BP 详情
addWorksheet(wb, "Detail_GO_BP")
writeData(wb, "Detail_GO_BP", go_bp_det)

saveWorkbook(wb, OUT_XLSX, overwrite = TRUE)

cat("--------------------------------------------------\n")
cat("✅ 成功！所有冲突已修复。\n")
cat("📄 文件已保存至:", OUT_XLSX, "\n")
cat("--------------------------------------------------\n")
# Out:
# Warning message:
# “程辑包‘readr’是用R版本4.2.3 来建造的”
# ✅ 成功读取 CSV。列名预览: Cluster Spectra_Label Overlap_Count Jaccard_Score Key_Markers Top_5_Genes_Input
# 正在提取 Hallmark...
# 正在提取 Reactome...
# 正在提取 GO_BP...
# --------------------------------------------------
# ✅ 成功！所有冲突已修复。
# 📄 文件已保存至: ./3.2.Neu_pathway/3.2.2.Neutrophils_GEP30_Cluster_Pathway_Master_Annotation.xlsx
# --------------------------------------------------
